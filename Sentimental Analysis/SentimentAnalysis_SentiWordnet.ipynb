# %% [markdown]
#  # <center> Lab 4 : Twitter sentiment Analysis

# %% [markdown]
# ### Name : Taha Nouali

# %% [markdown]
# ## part 1 : practical example using SentiWordnet

# %% [markdown]
# #**Importing Required Libraries**

# %%
import nltk
from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

nltk.download('wordnet')
nltk.download('sentiwordnet')
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
lemmatizer = WordNetLemmatizer()

sentence = "One of the best movie of all time. Period."
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\a\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package sentiwordnet to
# [nltk_data]     C:\Users\a\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\sentiwordnet.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\a\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\a\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\a\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.

# %% [markdown]
# #**Text PreProcessing**

# %% [markdown]
# #### (1) Removing Punctuations

# %%
punctuations = '''!()-[]{};:'"\,<>./?@#$%^&*_~'''

for x in sentence: 
  if x in punctuations: 
    sentence = sentence.replace(x, "")

print(sentence)
# Out:
# One of the best movie of all time Period

# %% [markdown]
# #### (2) Change Case + Tokenization

# %%
Tokens = nltk.word_tokenize(sentence.lower())
print(Tokens)
# Out:
# ['one', 'of', 'the', 'best', 'movie', 'of', 'all', 'time', 'period']

# %% [markdown]
# #### (3) Removing Stop Words - a, an, the, are, is etc.

# %%
stop_words = set(stopwords.words('english'))
clean_Tokens = [word for word in Tokens if word not in stop_words]
print(clean_Tokens)
# Out:
# ['one', 'best', 'movie', 'time', 'period']

# %% [markdown]
# #### (4) Lemmatization

# %%
lemma = [lemmatizer.lemmatize(word) for word in clean_Tokens]

print(lemma)
# Out:
# ['one', 'best', 'movie', 'time', 'period']

# %% [markdown]
# #### (5) POS Tagging

# %% [markdown]
# A part-of-speech tagger, or POS-tagger, processes a sequence of words, and attaches a part of speech tag to each word (don't forget to import nltk)

# %%
lemma
# Out:
# ['one', 'best', 'movie', 'time', 'period']

# %%
help(nltk.pos_tag)
# Out:
# Help on function pos_tag in module nltk.tag:
#
# pos_tag(tokens, tagset=None, lang='eng')
#     Use NLTK's currently recommended part of speech tagger to
#     tag the given list of tokens.
#
#         >>> from nltk.tag import pos_tag
#         >>> from nltk.tokenize import word_tokenize
#         >>> pos_tag(word_tokenize("John's big idea isn't all that bad.")) # doctest: +NORMALIZE_WHITESPACE
#         [('John', 'NNP'), ("'s", 'POS'), ('big', 'JJ'), ('idea', 'NN'), ('is', 'VBZ'),
#         ("n't", 'RB'), ('all', 'PDT'), ('that', 'DT'), ('bad', 'JJ'), ('.', '.')]
#         >>> pos_tag(word_tokenize("John's big idea isn't all that bad."), tagset='universal') # doctest: +NORMALIZE_WHITESPACE
#         [('John', 'NOUN'), ("'s", 'PRT'), ('big', 'ADJ'), ('idea', 'NOUN'), ('is', 'VERB'),
#         ("n't", 'ADV'), ('all', 'DET'), ('that', 'DET'), ('bad', 'ADJ'), ('.', '.')]
#
#     NB. Use `pos_tag_sents()` for efficient tagging of more than one sentence.
#
#     :param tokens: Sequence of tokens to be tagged
#     :type tokens: list(str)
#     :param tagset: the tagset to be used, e.g. universal, wsj, brown
#     :type tagset: str
#     :param lang: the ISO 639 code of the language, e.g. 'eng' for English, 'rus' for Russian
#     :type lang: str
#     :return: The tagged tokens
#     :rtype: list(tuple(str, str))

# %%
pos_val = nltk.pos_tag(lemma)
print(pos_val)

pos=neg=obj=count=0
# Out:
# [('one', 'CD'), ('best', 'JJS'), ('movie', 'NN'), ('time', 'NN'), ('period', 'NN')]

# %% [markdown]
# CC, a coordinating conjunction;
#
# RB, or adverbs;
#
# IN, a preposition;
#
# NN, a noun;
#
# JJ, an adjective.

# %% [markdown]
# The most popular tag set is Penn Treebank tagset. Most of the already trained taggers for English are trained on this tag set. To view the complete list, follow this link--> https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html.

# %%
# We can get more details about any POS tag using help funciton of NLTK as follows.
nltk.download('tagsets')
nltk.help.upenn_tagset("JJS$")
# Out:
# [nltk_data] Downloading package tagsets to
# [nltk_data]     C:\Users\a\AppData\Roaming\nltk_data...
# JJS: adjective, superlative
#     calmest cheapest choicest classiest cleanest clearest closest commonest
#     corniest costliest crassest creepiest crudest cutest darkest deadliest
#     dearest deepest densest dinkiest ...
# [nltk_data]   Unzipping help\tagsets.zip.

# %%
#nltk.download('universal_tagset')
nltk.download('universal_tagset')
pos_val2 = nltk.pos_tag(lemma, tagset='universal')
print(pos_val2)
# Out:
# [('dont', 'NOUN')]
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\a\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!

# %% [markdown]
# #**Functions for Sentiment Scoring**

# %%
# Convert between the PennTreebank tags to simple Wordnet tags
def penn_to_wn(tag):
    if tag.startswith('J'):
        return wn.ADJ
    elif tag.startswith('N'):
        return wn.NOUN
    elif tag.startswith('R'):
        return wn.ADV
    elif tag.startswith('V'):
        return wn.VERB
    return None

# %% [markdown]
# you can find the whol peeTreebank here https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html

# %%
# Returns list of pos-neg and objective score. But returns empty list if not present in senti wordnet.
def get_sentiment(word,tag):
    wn_tag = penn_to_wn(tag)
    
    if wn_tag not in (wn.NOUN, wn.ADJ, wn.ADV, wn.VERB):
        return []

    #Lemmatization
    #lemma = lemmatizer.lemmatize(word, pos=wn_tag)
    #if not lemma:
     #   return []

    #Synset is a special kind of a simple interface that is present in NLTK to look up words in WordNet. 
    #Synset instances are the groupings of synonymous words that express the same concept. 
    #Some of the words have only one Synset and some have several.
    synsets = wn.synsets(word, pos=wn_tag)
    if not synsets:
        return []

    # Take the first sense, the most common
    synset = synsets[0]
    swn_synset = swn.senti_synset(synset.name())

    return [synset.name(), swn_synset.pos_score(),swn_synset.neg_score(),swn_synset.obj_score()]

# %%
get_sentiment('happy', 'J')
# Out:
# ['happy.a.01', 0.875, 0.0, 0.125]

# %%
senti_val = [get_sentiment(x,y) for (x,y) in pos_val]
print(senti_val)
# Out:
# [[], ['best.a.01', 0.75, 0.0, 0.25], ['movie.n.01', 0.0, 0.0, 1.0], ['time.n.01', 0.0, 0.0, 1.0], ['time_period.n.01', 0.125, 0.125, 0.75]]

# %% [markdown]
# #**Aggregating Scores**

# %%
for i in range(len(senti_val)):
  try:
    pos = pos + senti_val[i][1]
    neg = neg + senti_val[i][2]
    obj = obj + senti_val[i][3]
  
  except:
    continue

# %%
print("Positive weight : {0} ".format(pos))
print("Negative weight : {0} ".format(neg))
print("Sentiment of the statement is {0} ".format(pos - neg))
# Out:
# Positive weight : 0.875
# Negative weight : 0.125
# Sentiment of the statement is 0.75

# %% [markdown]
# ## part 2: twitter sentiment Analysis

# %%
#data
#!pip install openpyxl

# %%
import pandas as pd
Tweet = pd.read_excel("US_Airline_Tweets.xlsx") # Weather_Final.csv # Airline_Final.csv

# %%
data=Tweet['Tweets']
data
# Out:
# 0                    @VirginAmerica What @dhepburn said.
# 1      @VirginAmerica plus you've added commercials t...
# 2      @VirginAmerica I didn't today... Must mean I n...
# 3      @VirginAmerica it's really aggressive to blast...
# 4      @VirginAmerica and it's a really big bad thing...
#                              ...
# 995    @united #UnitedAirlines Pls Fix #AspenBaggageF...
# 996    @united Read my bio. See who I work with. I ha...
# 997    @united Does customer care have email or a pho...
# 998    Thank you â€œ@united: @TRUU_Tall I can certain...
# 999    @united In the process of recovering their car...
# Name: Tweets, Length: 1000, dtype: object

# %%
import re 
#preprocessing
def tweet_preprocess(raw_tweet):
    
    raw_tweet = re.sub("@\w+","",raw_tweet).strip()
    raw_tweet = re.sub("http\S+","",raw_tweet).strip()
    letters_only = re.sub("[^a-zA-Z]", " ",raw_tweet) 
    words = letters_only.lower().split()                             
    stops = set(stopwords.words("english"))                  
    meaningful_words = [w for w in words if not w in stops] 
    lemma = [lemmatizer.lemmatize(word) for word in meaningful_words]
    return lemma#( " ".join( meaningful_words ))

# %%
new_data=[]
for raw in data:
    raw=tweet_preprocess(raw)
    new_data.append(raw)
    print(raw)
# Out:
# ['said']
# ['plus', 'added', 'commercial', 'experience', 'tacky']
# ['today', 'must', 'mean', 'need', 'take', 'another', 'trip']
# ['really', 'aggressive', 'blast', 'obnoxious', 'entertainment', 'guest', 'face', 'amp', 'little', 'recourse']
# ['really', 'big', 'bad', 'thing']
# ['seriously', 'would', 'pay', 'flight', 'seat', 'playing', 'really', 'bad', 'thing', 'flying', 'va']
# ['yes', 'nearly', 'every', 'time', 'fly', 'vx', 'ear', 'worm', 'go', 'away']
# ['really', 'missed', 'prime', 'opportunity', 'men', 'without', 'hat', 'parody']
# ['well']
# ['amazing', 'arrived', 'hour', 'early', 'good']
# ['know', 'suicide', 'second', 'leading', 'cause', 'death', 'among', 'teen']
# ['lt', 'pretty', 'graphic', 'much', 'better', 'minimal', 'iconography']
# ['great', 'deal', 'already', 'thinking', 'nd', 'trip', 'amp', 'even', 'gone', 'st', 'trip', 'yet', 'p']
# ['flying', 'fabulous', 'seductive', 'sky', 'u', 'take', 'stress', 'away', 'travel']
# ['thanks']
# ['sfo', 'pdx', 'schedule', 'still', 'mia']
# ['excited', 'first', 'cross', 'country', 'flight', 'lax', 'mco', 'heard', 'nothing', 'great', 'thing', 'virgin', 'america', 'daystogo']
# ['flew', 'nyc', 'sfo', 'last', 'week', 'fully', 'sit', 'seat', 'due', 'two', 'large', 'gentleman', 'either', 'side', 'help']
# ['flying']
# ['know', 'would', 'amazingly', 'awesome', 'bos', 'fll', 'please', 'want', 'fly']
# ['first', 'fare', 'may', 'three', 'time', 'carrier', 'seat', 'available', 'select']
# ['love', 'graphic']
# ['love', 'hipster', 'innovation', 'feel', 'good', 'brand']
# ['making', 'bos', 'gt', 'la', 'non', 'stop', 'permanently', 'anytime', 'soon']
# ['guy', 'messed', 'seating', 'reserved', 'seating', 'friend', 'guy', 'gave', 'seat', 'away', 'want', 'free', 'internet']
# ['status', 'match', 'program', 'applied', 'three', 'week', 'called', 'emailed', 'response']
# ['happened', 'ur', 'vegan', 'food', 'option', 'least', 'say', 'ur', 'site', 'know', 'able', 'eat', 'anything', 'next', 'hr', 'fail']
# ['miss', 'worry', 'together', 'soon']
# ['amazing', 'get', 'cold', 'air', 'vent', 'vx', 'noair', 'worstflightever', 'roasted', 'sfotobos']
# ['lax', 'ewr', 'middle', 'seat', 'red', 'eye', 'noob', 'maneuver', 'sendambien', 'andchexmix']
# ['hi', 'bked', 'cool', 'birthday', 'trip', 'add', 'elevate', 'cause', 'entered', 'middle', 'name', 'flight', 'booking', 'problem']
# ['hour', 'operation', 'club', 'sfo', 'posted', 'online', 'current']
# ['help', 'left', 'expensive', 'headphone', 'flight', 'iad', 'lax', 'today', 'seat', 'one', 'answering', 'l', 'amp', 'f', 'number', 'lax']
# ['awaiting', 'return', 'phone', 'call', 'would', 'prefer', 'use', 'online', 'self', 'service', 'option']
# ['great', 'news', 'america', 'could', 'start', 'flight', 'hawaii', 'end', 'year', 'via']
# ['nice', 'rt', 'vibe', 'moodlight', 'takeoff', 'touchdown', 'moodlitmonday', 'sciencebehindtheexperience']
# ['moodlighting', 'way', 'fly', 'best', 'experience', 'ever', 'cool', 'calming', 'moodlitmonday']
# ['done', 'done', 'best', 'airline', 'around', 'hand']
# ['book', 'flight', 'hawaii']
# ['chat', 'support', 'working', 'site']
# ['view', 'downtown', 'los', 'angeles', 'hollywood', 'sign', 'beyond', 'rain', 'mountain']
# ['hey', 'first', 'time', 'flyer', 'next', 'week', 'excited', 'hard', 'time', 'getting', 'flight', 'added', 'elevate', 'account', 'help']
# ['plz', 'help', 'win', 'bid', 'upgrade', 'flight', 'lax', 'gt', 'sea']
# ['unused', 'ticket', 'moved', 'new', 'city', 'fly', 'fly', 'expires', 'travelhelp']
# ['flight', 'leaving', 'dallas', 'seattle', 'time', 'feb']
# ['elevategold', 'good', 'reason', 'rock']
# ['dream']
# ['wow', 'blew', 'mind']
# ['last', 'night', 'tribute', 'soundofmusic', 'oscar', 'think', 'agree']
# ['entertaining']
# ['flight', 'way', 'supposed', 'take', 'minute', 'ago', 'website', 'still', 'show', 'time', 'flight', 'thanks']
# ['julie', 'andrew', 'way', 'though', 'impressive']
# ['wish', 'flew', 'atlanta', 'soon']
# ['julie', 'andrew', 'hand']
# ['flight', 'leaving', 'dallas', 'la', 'february', 'th']
# ['hi', 'excited', 'lga', 'gt', 'dal', 'deal', 'trying', 'book', 'since', 'last', 'week', 'amp', 'page', 'never', 'load', 'thx']
# ['know', 'need', 'spotify', 'stat', 'guiltypleasures']
# ['lady', 'gaga', 'amazing']
# ['carrie']
# ['new', 'marketing', 'song', 'let', 'u', 'know', 'think']
# ['julie', 'andrew', 'first', 'lady', 'gaga', 'wow', 'last', 'night', 'carrie', 'meh']
# ['called', 'week', 'ago', 'adding', 'flight', 'elevate', 'still', 'shown', 'help']
# ['great', 'go', 'carrieunderwood']
# ['sorry', 'mary', 'martin', 'first']
# ['love', 'three', 'really', 'beat', 'classic']
# ['flight', 'dal', 'dca', 'pm', 'tried', 'check', 'could', 'status', 'please']
# ['heyyyy', 'guyyyys', 'trying', 'get', 'hour', 'someone', 'call', 'please']
# ['hi', 'virgin', 'hold', 'minute', 'earlier', 'flight', 'la', 'nyc', 'tonight', 'earlier', 'pm']
# ['congrats', 'winning', 'award', 'best', 'deal', 'airline', 'u']
# ['everything', 'fine', 'lost', 'bag']
# ['need', 'change', 'reservation', 'virgin', 'credit', 'card', 'need', 'modify', 'phone', 'waive', 'change', 'fee', 'online']
# ['emailed', 'customer', 'service', 'team', 'let', 'know', 'need', 'tracking', 'number']
# ['hi', 'booked', 'flight', 'need', 'add', 'baggage']
# ['airline', 'awesome', 'lax', 'loft', 'need', 'step', 'game', 'dirty', 'table', 'floor']
# ['worried', 'great', 'ride', 'new', 'plane', 'great', 'crew', 'airline', 'like']
# ['awesome', 'flew', 'yall', 'sat', 'morning', 'way', 'correct', 'bill']
# ['watch', 'best', 'student', 'film', 'country', 'foot', 'cmfat', 'foot']
# ['first', 'time', 'flying', 'different', 'rate', 'policy', 'medium', 'bag', 'thanks']
# ['going', 'customer', 'service', 'anyway', 'speak', 'human', 'asap', 'thank']
# ['happened', 'doom']
# ['supp', 'biz', 'traveler', 'like', 'customer', 'service', 'like', 'neverflyvirginforbusiness']
# ['applied', 'member', 'inflight', 'crew', 'team', 'im', 'interested', 'flightattendant', 'dreampath', 'g']
# ['best', 'whenever', 'begrudgingly', 'use', 'airline', 'delayed', 'late', 'flight']
# ['interesting', 'flying', 'cancelled', 'flight', 'next', 'four', 'flight', 'planned', 'neverflyvirginforbusiness']
# ['disappointing', 'experience', 'shared', 'every', 'business', 'traveler', 'meet', 'neverflyvirgin']
# ['trouble', 'adding', 'flight', 'wife', 'booked', 'elevate', 'account', 'help']
# ['bring', 'reservation', 'online', 'using', 'flight', 'booking', 'problem', 'code']
# ['random', 'q', 'distribution', 'elevate', 'avatar', 'bet', 'kitty', 'disproportionate', 'share']
# ['lt', 'flying', 'va', 'life', 'happens', 'trying', 'change', 'trip', 'jperhi', 'help', 'va', 'home', 'page', 'let']
# ['site', 'back']
# ['rnp', 'yeah', 'know']
# ['hi', 'get', 'point', 'elevate', 'account', 'recent', 'flight', 'add', 'flight', 'point', 'account']
# ['like', 'tv', 'interesting', 'video', 'disappointed', 'cancelled', 'flightled', 'flight', 'flight', 'went', 'jfk', 'saturday']
# ['landed', 'lax', 'hour', 'late', 'flight', 'bag', 'check', 'business', 'travel', 'friendly', 'nomorevirgin']
# ['flight', 'redirected']
# ['website', 'btw', 'new', 'website', 'great', 'user', 'experience', 'time', 'another', 'redesign']
# ['check', 'add', 'bag', 'website', 'working', 'tried', 'desktop', 'mobile']
# ['let', 'scanned', 'passenger', 'leave', 'plane', 'told', 'someone', 'remove', 'bag', 'st', 'class', 'bin', 'uncomfortable']
# ['phone', 'number', 'find', 'call', 'flight', 'reservation']
# ['anyone', 'anything', 'today', 'website', 'useless', 'one', 'answering', 'phone']
# ['trying', 'add', 'boy', 'prince', 'ressie', 'sf', 'thursday', 'lax']
# ['must', 'traveler', 'miss', 'flight', 'late', 'flight', 'check', 'bag', 'missed', 'morning', 'appointment', 'lost', 'business', 'sfo', 'lax']
# ['check', 'new', 'music']
# ['direct', 'flight', 'fll', 'gt', 'sfo', 'unexpected', 'layover', 'vega', 'fuel', 'yet', 'peep', 'next', 'bought', 'vega', 'flight', 'sneaky']
# ['late', 'flight', 'bag', 'check', 'lost', 'business', 'missed', 'flight', 'apt', 'three', 'people', 'flight', 'exp']
# ['amazing', 'customer', 'service', 'raeann', 'sf', 'best', 'customerservice', 'virginamerica', 'flying']
# ['called', 'service', 'line', 'hung', 'awesome', 'sarcasm']
# ['site', 'tripping', 'trying', 'check', 'getting', 'plain', 'text', 'version', 'reluctant', 'enter', 'card', 'info']
# ['scheduled', 'sfo', 'dal', 'flight', 'today', 'changed', 'th', 'due', 'weather', 'look', 'like', 'flight', 'still']
# ['getaway', 'deal', 'may', 'one', 'way', 'lot', 'cool', 'city', 'cheapflights', 'farecompare']
# ['getaway', 'deal', 'may', 'one', 'way', 'lot', 'cool', 'city', 'cheapflights', 'farecompare']
# ['getaway', 'deal', 'may', 'one', 'way', 'lot', 'cool', 'city', 'cheapflights', 'farecompare']
# ['getaway', 'deal', 'may', 'one', 'way', 'lot', 'cool', 'city', 'cheapflights', 'farecompare']
# ['great', 'week']
# ['come', 'back', 'phl', 'already', 'need', 'take', 'u', 'horrible', 'cold', 'pleasecomeback']
# ['concerned', 'fly', 'plane', 'need', 'delayed', 'due', 'tech', 'stop']
# ['best', 'airline', 'flown', 'easy', 'change', 'reservation', 'helpful', 'representative', 'amp', 'comfortable', 'flying', 'experience']
# ['another', 'rep', 'kicked', 'butt', 'naelah', 'represents', 'team', 'beautifully', 'thank']
# ['beautiful', 'front', 'end', 'design', 'right', 'cool', 'still', 'book', 'ticket', 'b', 'c', 'back', 'end', 'secure']
# ['love', 'team', 'running', 'gate', 'e', 'la', 'tonight', 'waited', 'delayed', 'flight', 'kept', 'thing', 'entertaining']
# ['use', 'another', 'browser', 'amp', 'brand', 'reputation', 'built', 'tech', 'response', 'cross', 'browser', 'compatible', 'website']
# ['flight', 'flight', 'booking', 'problem', 'site', 'totally', 'folk', 'problem']
# ['like', 'customer', 'service', 'min', 'delay', 'connecting', 'passenger', 'seems', 'long', 'va']
# ['thanks', 'outstanding', 'nyc', 'jfk', 'crew', 'moved', 'mountain', 'get', 'home', 'san', 'francisco', 'tonight']
# ['absolute', 'best', 'team', 'customer', 'service', 'ever', 'every', 'time', 'fly', 'delighted', 'thank']
# ['provide', 'complimentary', 'upgrade', 'first', 'class', 'available', 'seat']
# ['need', 'change', 'flight', 'thats', 'scheduled', 'hour', 'min', 'wait', 'time', 'phone', 'im', 'calling', 'intern', 'help']
# ['completely', 'awesome', 'experience', 'last', 'month', 'bos', 'la', 'nonstop', 'thanks', 'awesome', 'flight', 'depart', 'time', 'vabeatsjblue']
# ['watch', 'oscar', 'jfk', 'gt', 'sfo', 'flight']
# ['flight', 'cancelled', 'flightled']
# ['failing', 'customer', 'check', 'process', 'link', 'tsa', 'pre', 'check']
# ['u', 'terrible', 'airline', 'gave', 'u', 'hotel', 'hotline', 'number', 'said', 'sorry']
# ['flight', 'number', 'sfo', 'cabo', 'san', 'lucas', 'arrived', 'yet']
# ['assistance', 'yesterday', 'u', 'cancelled', 'flightled', 'flight', 'give', 'u', 'hotel', 'hotline', 'shame']
# ['another', 'delayed', 'flight', 'likingyoulessandless']
# ['need', 'register', 'service', 'dog', 'first', 'class', 'ticket', 'sfo', 'gt', 'dulles', 'phone', 'queue', 'hour', 'longer', 'pls', 'advise']
# ['rock', 'making', 'watch', 'oscar', 'flight', 'redcarpet', 'oscar', 'oscar']
# ['dropped', 'track']
# ['always', 'xoxo']
# ['book', 'seat', 'flight', 'buy', 'even', 'check', 'creates', 'much', 'anxiety', 'frustrated']
# ['think', 'paying', 'extra', 'buck', 'rt', 'luggage', 'might', 'afford', 'hiring', 'extra', 'hand', 'lame']
# ['best', 'customer', 'service', 'rep', 'world', 'irmafromdallas', 'take', 'cake']
# ['find', 'u', 'flt', 'lax', 'sooner', 'midnight', 'monday', 'would', 'great', 'customer', 'service']
# ['please', 'provide', 'status', 'flight', 'cant', 'imagine', 'time', 'web', 'indicates', 'dude', 'weather', 'dallas']
# ['amazing', 'staff', 'amp', 'super', 'helpful', 'ran', 'princesshalf', 'spoiled', 'comfort']
# ['paid', 'premium', 'fly', 'across', 'country', 'cancelled', 'flight', 'flight', 'offer', 'check', 'fee', 'upgrade', 'love', 'sad', 'face']
# ['question', 'possible', 'book', 'seat', 'infant', 'giving', 'option', 'want', 'seat']
# ['always', 'together', 'welcome', 'rt', 'welcome']
# ['flight', 'home', 'dc', 'sunset', 'globe', 'backtowinter', 'back', 'work', 'refreshed']
# ['understand', 'need', 'dm', 'give', 'answer', 'damaged', 'luggage', 'policy']
# ['mean', 'policy', 'destroyed', 'luggage']
# ['special', 'assistance', 'travel', 'alone', 'w', 'kid', 'infant', 'priority', 'boarding']
# ['thank', 'checking', 'ticket', 'purchased', 'customer', 'happy']
# ['website', 'ever', 'coming', 'back', 'online']
# ['flight', 'love', 'field', 'sfo', 'definitely', 'cancelled', 'flightled', 'monday', 'february']
# ['flight', 'lga', 'dfw', 'time']
# ['driver', 'license', 'expired', 'little', 'month', 'fly', 'friday', 'morning', 'using', 'expired', 'license']
# ['problem', 'flight', 'booking', 'problem', 'web', 'site', 'keep', 'giving', 'error', 'contact', 'phone', 'phone', 'minute', 'wait']
# ['reschedule', 'cancelled', 'flightled', 'flight', 'online', 'change', 'button', 'greyed']
# ['rang', 'wait', 'minute', 'book', 'ticket', 'vendor', 'fix', 'site']
# ['got', 'flight', 'told', 'today', 'checked', 'email', 'tomorrow', 'unacceptable']
# ['flight', 'lga', 'cancelled', 'flighted', 'stuck', 'dallas', 'called', 'reschedule', 'told', 'could', 'get', 'flight', 'today']
# ['pairing', 'include', 'red', 'wine', 'white', 'offered', 'redwineisbetter']
# ['website']
# ['site', 'seems', 'little', 'wonked', 'right', 'may', 'want', 'look', 'tried', 'two', 'browser', 'cs']
# ['disappointed', 'agent', 'designated', 'silver', 'status', 'check', 'line', 'closed', 'assist', 'pasengers']
# ['plan', 'include', 'austin', 'dallas', 'route', 'topnews', 'arab', 'emirate']
# ['normal', 'receive', 'reply', 'central', 'baggage', 'baggageissues', 'smh']
# ['logan', 'airport', 'waiting', 'checkin', 'flight', 'checkin', 'desk', 'open']
# ['jump', 'dallas', 'austin', 'market']
# ['beat', 'eps', 'view', 'take', 'southwestair', 'va', 'luv', 'investor', 'business', 'daily']
# ['lister', 'show', 'monday']
# ['begin', 'dallas', 'austin', 'flight', 'april', 'ketr']
# ['congrats', 'got', 'business', 'ewr', 'sfo', 'lax', 'fuck', 'fl', 'sfo', 'ewr', 'clincher']
# ['applied', 'week', 'ago', 'heard', 'back', 'flying', 'week', 'disappointed']
# ['love', 'know', 'policy', 'damaged', 'luggage']
# ['thank', 'follow']
# ['many', 'apology', 'r', 'worse', 'airline', 'even', 'respond', 'cudtomers']
# ['shame', 'va', 'making', 'people', 'spend', 'money', 'stranded', 'city', 'airline', 'landing', 'jfk', 'reimburse']
# ['dm']
# ['please', 'flight', 'sjc', 'choice', 'fly', 'southwest', 'vega']
# ['bad', 'say', 'take', 'day', 'via', 'confirmation', 'email', 'inquired', 'week', 'claim', 'week']
# ['flight', 'bos', 'gt', 'la', 'tomorrow', 'cancelled', 'flightled', 'notification', 'wait', 'time', 'hour', 'rebook', 'another', 'airline']
# ['rt', 'met', 'match', 'got', 'status', 'another', 'airline', 'upgrade', 'restr']
# ['way', 'fly', 'elevate', 'gold']
# ['guy', 'flight', 'cmh']
# ['lot', 'apology', 'thrown', 'customer', 'see', 'sad', 'thanks', 'nothing', 'worst', 'airline', 'ever']
# ['flight', 'stuff', 'wrong', 'nothing', 'worst', 'flight', 'ever']
# ['issue', 'finding', 'missing', 'item', 'plane', 'help', 'find', 'airport', 'plane', 'headed', 'next']
# ['match', 'americanairlines', 'status', 'cool']
# ['met', 'match', 'got', 'status', 'another', 'airline', 'upgrade']
# ['trying', 'book', 'flight', 'guy', 'website', 'let', 'lose', 'business']
# ['suck']
# ['thanks']
# ['dm', 'issue', 'persisting']
# ['never', 'rec', 'cancelled', 'flightlation', 'notice', 'left', 'w', 'option', 'fly', 'p', 'driving', 'la', 'red', 'eye', 'mon', 'w', 'kid']
# ['trying', 'book', 'flight', 'amp', 'site']
# ['flight', 'flying', 'boston', 'tomorrow', 'need', 'home', 'cancelled', 'flightled', 'flight', 'anything']
# ['stink', 'flight', 'cancelled', 'flighted', 'psp', 'jfk', 'notification', 'ability', 'rebook', 'disappointed', 'expected', 'better']
# ['love', 'guy', 'song', 'dancing', 'high', 'school', 'dance', 'revue']
# ['website', 'trying', 'check']
# ['done', 'thank', 'quick', 'response', 'apparently', 'faster', 'sitting', 'hold']
# ['nervous', 'flight', 'dc', 'lax', 'getting', 'cancelled', 'flightled', 'tomorrow', 'sent', 'dm', 'help']
# ['cool', 'picture', 'another', 'virginamerica', 'plane', 'wing', 'site']
# ['keep', 'great', 'work']
# ['goodness', 'people', 'field', 'amazing', 'pressure', 'texas', 'beatstheothers', 'crisis', 'please', 'fly', 'ny']
# ['thanks', 'great', 'flight', 'la', 'boston', 'pilot', 'great', 'job', 'landing', 'snow', 'go', 'back', 'la', 'seriously']
# ['please', 'get', 'new', 'york', 'area', 'monday', 'afternoon']
# ['thanks', 'much', 'awesome', 'support', 'guy', 'rock']
# ['seat', 'row', 'recline', 'mention', 'website', 'soreback']
# ['flight', 'delayed', 'hour', 'la', 'due', 'mechanical', 'problem', 'handle', 'like', 'pro', 'could', 'tossed', 'u', 'free', 'drink']
# ['cancelled', 'flight', 'flight', 'today', 'precipitation', 'scared']
# ['twitter', 'team', 'guy', 'killed', 'rescheduling', 'asap', 'thank']
# ['guy', 'charged', 'reschedule', 'flight', 'cancelled', 'flighted', 'refusing', 'refund', 'deal']
# ['access', 'website', 'safari', 'iphone', 'seems', 'work', 'mac', 'ipad', 'need', 'iphone', 'add', 'passbook']
# ['ipad', 'iphone', 'clicking', 'checkin', 'link', 'email', 'received', 'hr', 'flight']
# ['really', 'looking', 'forward', 'flight', 'let', 'know', 'rescheduled', 'diehardvirgin']
# ['cancelled', 'flight', 'flight', 'vx', 'one', 'sec', 'delayed', 'airport', 'next', 'cancelled', 'flightled', 'gonna', 'email', 'call', 'reschedule']
# ['problem', 'link', 'email', 'check', 'thanks']
# ['change', 'another', 'airline', 'get', 'dc', 'today', 'able', 'land', 'dc', 'cost', 'ugh']
# ['looking', 'forward', 'first', 'flight', 'today', 'cancelled', 'flightled', 'along', 'subsequent', 'one']
# ['putting', 'great', 'deal', 'pdx', 'la', 'la', 'pdx', 'show', 'love']
# ['wish', 'afford', 'fly', 'next', 'friday', 'going', 'back', 'home', 'love', 'everything', 'airline']
# ['gonna', 'deal', 'dallas', 'dc', 'deal', 'dc', 'dallas', 'sad']
# ['bug', 'report', 'guy']
# ['hold', 'time', 'call', 'center', 'bit', 'much']
# ['like']
# ['site', 'help']
# ['best', 'flight', 'attendant', 'ever']
# ['awesome', 'rt', 'watch', 'nominated', 'film', 'foot', 'meetthefleet', 'oscar']
# ['thanks', 'much']
# ['trying', 'reset', 'password', 'email', 'never', 'arrives', 'help']
# ['airline', 'based', 'silicon', 'valley', 'disruption', 'fcmostinnovative', 'incubator']
# ['nicely', 'done']
# ['looking', 'forward', 'watching', 'oscar', 'flight', 'home', 'tomorrow', 'might', 'even', 'get', 'something', 'bubbly', 'drink']
# ['reason', 'delay', 'departure', 'vx', 'jfk', 'afternoon']
# ['today', 'flight', 'palm', 'spring', 'ca', 'jfk', 'ny', 'cancelled', 'flightled']
# ['hahaha', 'guy', 'amazing', 'love', 'guy']
# ['sound', 'like', 'fun']
# ['update', 'flight', 'jfk', 'gt', 'lax']
# ['spruce', 'moose']
# ['cs', 'site', 'right', 'please', 'fix', 'site', 'unusable']
# ['flight', 'vega', 'boston', 'today', 'checked', 'online', 'bag', 'count', 'register', 'fix', 'somehow']
# ['classiq', 'luv', 'virgin', 'america', 'greetingz']
# ['hi', 'trying', 'check', 'website', 'working', 'tried', 'different', 'browser', 'problem', 'continues']
# ['thanks', 'great', 'customer', 'service', 'today', 'amp', 'helping', 'get', 'travel', 'sorted']
# ['thanks', 'guy', 'sweet', 'route', 'rockies', 'airplanemodewason']
# ['love', 'music', 'blasting', 'gate', 'boston', 'waiting', 'flight', 'sanfrancisco', 'could', 'get', 'iced', 'coffee']
# ['passenger', 'flt', 'assaulted', 'flown', 'trust', 'banned', 'crew', 'filed', 'report']
# ['current', 'bug', 'website', 'show', 'select', 'departure', 'city', 'selecting', 'destination', 'city']
# ['luggage', 'severely', 'dented', 'missing', 'wheel', 'coming', 'baggage', 'claim', 'san', 'luggage', 'agent', 'miranda', 'think', 'help']
# ['thank', 'easy', 'itinerary', 'shift', 'impending', 'weather', 'quick', 'painless', 'amp', 'free']
# ['love', 'see', 'girl', 'inspired', 'become', 'pilot', 'rt', 'free', 'woaw', 'event', 'march', 'abq']
# ['thanks', 'good', 'time', 'back', 'vodkatonics', 'entire', 'flight', 'sfo']
# ['beat', 'expectation', 'share', 'take', 'santa', 'cruz', 'sentinel']
# ['plan', 'start', 'flying', 'direct', 'dal', 'la']
# ['big', 'love', 'gratitude', 'mpower', 'w', 'werin', 'oscar', 'vipswagbags', 'avalonhollywood']
# ['great', 'job', 'adding', 'little', 'luxury', 'aesthetic', 'improve', 'air', 'travel', 'experience', 'thank', 'keep']
# ['requested', 'window', 'seat', 'confirmed', 'window', 'got', 'stuck', 'middle', 'seat', 'good', 'way', 'treat', 'silver', 'member']
# ['grand', 'budapest', 'hotel', 'oscarscountdown']
# ['missed', 'next', 'trip']
# ['wtf', 'paid', 'direct', 'flight', 'purpose', 'stop', 'fuel', 'exhausted', 'frequent', 'flier', 'nothing', 'inconvenience']
# ['something', 'wrong', 'website', 'safari', 'iphone']
# ['thanks', 'gate', 'checking', 'baggage', 'full', 'flight', 'dfw', 'lax', 'giving', 'early', 'boarding', 'sweet']
# ['already', 'checked', 'page', 'expired', 'x']
# ['boo', 'refunding', 'seat', 'upgrade', 'fee', 'want', 'buy', 'first', 'place']
# ['share', 'rise', 'q', 'financial', 'result', 'usa', 'today']
# ['add', 'pillow', 'instead', 'lie', 'flat', 'seat', 'first', 'class', 'arm', 'race']
# ['see']
# ['way', 'take', 'advantage', 'mayweatherpacquiao']
# ['know', 'flying', 'virgin', 'fight', 'mayweatherpacquiao']
# ['inflight', 'team', 'make', 'experience', 'amazing']
# ['cutest', 'salt', 'pepper', 'shaker', 'ever', 'think', 'guy', 'get', 'better']
# ['moved', 'seat', 'notice', 'better', 'seat', 'cabin', 'select', 'behind', 'row', 'selected', 'disappointed']
# ['share', 'q', 'result']
# ['fav', 'airline']
# ['hot', 'female', 'pilot', 'sweet', 'dca', 'sfo']
# ['guy', 'going', 'start', 'flying', 'paris', 'welcome']
# ['policy', 'flying', 'surgery', 'still', 'waiting', 'answer', 'tell', 'doctor']
# ['already', 'contacted', 'central', 'baggage', 'amp', 'sent', 'dm', 'charging', 'dress', 'lost', 'suitcase', 'help']
# ['thank']
# ['anything', 'going', 'website', 'getting', 'lot', 'error', 'past', 'minute']
# ['think', 'left', 'something', 'plane', 'yesterday', 'call', 'ah']
# ['need', 'follow', 'back', 'order', 'dm']
# ['need', 'start', 'flying']
# ['told', 'check', 'airline', 'regulation', 'first', 'contacted']
# ['checked', 'flight', 'sfo', 'lax', 'amp', 'told', 'atlantic', 'flying', 'club', 'gold', 'get', 'benefit']
# ['husband', 'ordered', 'three', 'drink', 'via', 'screen', 'never', 'came', 'awesome']
# ['soooo', 'guy', 'going', 'leave', 'seatbelt', 'light', 'flight', 'barely', 'call', 'turbulence']
# ['policy', 'flying', 'surgery']
# ['post', 'second', 'consecutive', 'full', 'year', 'net', 'profit']
# ['funny', 'story', 'website', 'broken', 'missing', 'javascript', 'stylesheets', 'checkin', 'process', 'dislike']
# ['would', 'love', 'virgin', 'like']
# ['result', 'handily', 'exceed', 'forecast']
# ['applied', 'position', 'wondering', 'guy', 'received', 'application']
# ['achieves', 'second', 'year', 'profitability', 'despite', 'revenue', 'pressure']
# ['give', 'positive', 'outlook', 'see', 'increased', 'competition']
# ['trying', 'check', 'ct', 'flight', 'tmm', 'desktop', 'website', 'working', 'sort', 'caching', 'bug', 'so']
# ['weather', 'delay', 'gt', 'next', 'week', 'jfk', 'bos', 'dca']
# ['check', 'website', 'go', 'airport']
# ['guy', 'know', 'check', 'link', 'email', 'broken']
# ['pilot', 'say', 'expect', 'choppy', 'landing', 'nyc', 'due', 'gusty', 'wind', 'w', 'temperature', 'degree', 'amp', 'w', 'windchill']
# ['loved', 'wait', 'monday', 'return', 'flight', 'mostly', 'watch', 'inflight', 'safety', 'video', 'sorrynotsorry']
# ['lost', 'luggage', 'day', 'ago', 'flight', 'vx', 'lax', 'iad', 'amp', 'calling', 'every', 'day', 'response', 'please', 'give', 'back', 'stuff']
# ['flight', 'booking', 'problem', 'section', 'website', 'seems', 'broken', 'chrome', 'might', 'wanna', 'look']
# ['hi', 'wanted', 'see', 'new', 'route', 'planned', 'year', 'newark', 'love', 'flying', 'guy', 'hope']
# ['mean', 'probably', 'inappropriate', 'board']
# ['happy', 'spend', 'day', 'together', 'let']
# ['saving', 'sanity', 'right']
# ['missed', 'flight', 'standby', 'work']
# ['understanding', 'helped', 'thx', 'comp']
# ['brought', 'way', 'across', 'country', 'today', 'see']
# ['thank', 'absolutely']
# ['look', 'like', 'broken', 'link', 'asset']
# ['ready', 'let', 'say', 'together', 'noooo', 'turbulence', 'today']
# ['manage', 'itinerary', 'section', 'website', 'seems', 'broken']
# ['check', 'site', 'look', 'like', 'every', 'time', 'load']
# ['u', 'help', 'need', 'urgent', 'treatment', 'old', 'battling', 'cancer', 'could', 'u', 'help', 'flight', 'freyasfund']
# ['may', 'start', 'service', 'hawaii', 'sanfrancisco', 'year', 'biztravel']
# ['carrier', 'le', 'half', 'price', 'round', 'trip', 'fare', 'stunned']
# ['wtf', 'happening', 'pdx', 'late', 'flight', 'march', 'one', 'way', 'sfo']
# ['add', 'dtw', 'sold']
# ['free', 'drink', 'flight', 'back', 'free', 'promo']
# ['thanks']
# ['momma', 'made']
# ['please', 'contact', 'portfolio', 'left', 'flight', 'vx', 'jfk', 'sfo', 'tonite', 'seat', 'need', 'returned', 'call']
# ['help', 'flight', 'jkf', 'tonight', 'seat', 'c', 'left', 'portfolio', 'need', 'back']
# ['seattle', 'bound', 'wifey', 'got', 'duffle', 'vday', 'keeper', 'holla']
# ['luggage', 'gone', 'filed', 'paperwork', 'promised', 'call', 'email', 'still', 'resolution', 'response', 'central', 'luggage']
# ['debbie', 'baldwin', 'gave', 'rockstar', 'performance', 'safety', 'demo', 'evening', 'vx', 'la', 'sfo', 'bestcrew', 'sherocks']
# ['thanks']
# ['thanks', 'taking', 'care', 'flight', 'rockstars', 'travel']
# ['thanks', 'lovely', 'soft', 'view', 'travel', 'san', 'sfo']
# ['requested', 'mileage', 'challenge', 'status', 'several', 'week', 'ago', 'online', 'heard', 'back', 'get', 'help']
# ['trying', 'book', 'ticket', 'nyc', 'facing', 'super', 'fun', 'broken', 'styling', 'worry', 'keep', 'trying']
# ['applied', 'status', 'match', 'feb', 'got', 'confirmation', 'email', 'day', 'still', 'news', 'though', 'guy', 'dropped', 'ball', 'late', 'flightly']
# ['new', 'go', 'airline']
# ['adore', 'looking', 'forward', 'flight', 'austin', 'two', 'week']
# ['glad', 'mentioned', 'took', 'first', 'virgin', 'flight', 'year', 'back', 'transformative', 'experience']
# ['flight', 'booking', 'problem', 'flight', 'uphold', 'status', 'match', 'tax', 'ticket', 'count', 'earned', 'status', 'point', 'statusmatch', 'virginamerica']
# ['trying', 'check', 'look', 'like', 'site']
# ['spending', 'birthday', 'night', 'dal', 'dca', 'get', 'home']
# ['sent', 'couple', 'message', 'email', 'provided', 'avail', 'try', 'next', 'year', 'cheer']
# ['first', 'time', 'flying', 'virgin', 'went', 'sanfrancisco', 'thanks', 'smooth', 'ride', 'easily', 'new', 'fav', 'airline']
# ['seriously', 'though', 'direct', 'flight', 'sfo', 'fll', 'may']
# ['fine', 'already', 'done', 'purchase', 'try', 'go', 'way', 'go', 'back']
# ['really', 'experience', 'hoping', 'w', 'forced', 'check', 'small', 'carry', 'w', 'nothing', 'empty', 'cabin', 'space', 'board']
# ['jump', 'dallas', 'austin', 'market']
# ['spoke', 'representative', 'offered', 'solution', 'loyal', 'customer', 'fly', 'well']
# ['deeply', 'disappointed', 'birthday', 'promo', 'applied', 'trip', 'booked', 'mere', 'day', 'received', 'email']
# ['happened', 'direct', 'flight', 'sfo', 'fll', 'looking', 'may', 'see', 'connecting', 'help', 'dontdothistome']
# ['help', 'left', 'blazer', 'kooples', 'jacket', 'bag', 'rd', 'row', 'second', 'seat', 'right', 'gate', 'lax', 'flight', 'sfo']
# ['partner', 'checkout', 'mobile', 'payment', 'method', 'help', 'boost', 'mobile', 'conversion', 'rate', 'etailwest', 'payment', 'visa']
# ['promoting', 'product', 'problem', 'southwest', 'recommend', 'noneother', 'best']
# ['love', 'guy', 'pls', 'get', 'direct', 'route', 'la', 'au']
# ['would', 'like', 'help', 'flight', 'please']
# ['bruh', 'turn', 'vxsafetydance']
# ['course', 'work', 'obsessed', 'entire', 'virgin', 'family']
# ['ok', 'first', 'time', 'flying', 'tonight']
# ['digging', 'swanky', 'pink', 'mood', 'lighting', 'flight', 'nyc', 'sfo', 'need', 'cabaret', 'singer', 'think']
# ['done', 'need', 'receipt', 'asap', 'could', 'please', 'help']
# ['vx', 'jfk', 'la', 'dirty', 'plane', 'standard']
# ['flight', 'vx', 'headed', 'la', 'jfk', 'dirtiest', 'va', 'plane', 'ever', 'sad', 'great', 'airline']
# ['got', 'squared', 'away', 'someone', 'picked', 'soon', 'tweeted', 'tweeted', 'sooner']
# ['avis', 'rental', 'continue', 'button', 'work', 'website', 'book', 'car', 'tried', 'time', 'phone', 'suck']
# ['delayed']
# ['currently', 'minute', 'hold', 'cust', 'service', 'need', 'anything', 'add', 'lap', 'child', 'reservation']
# ['course', 'fun', 'celebrating', 'thanks', 'happy', 'chinese', 'new', 'year']
# ['flight', 'booking', 'problem', 'last', 'second', 'flight', 'next', 'week', 'sfo', 'san', 'chance', 'want', 'gift', 'promo', 'code', 'since', 'love', 'guy']
# ['comenity', 'bank', 'joke', 'please', 'change', 'nothing', 'constant', 'problem', 'bank']
# ['dm', 'u', 'also', 'add']
# ['grandma', 'ella', 'th', 'would', 'lt', 'bday', 'greeting', 'flight', 'crew', 'stewardess', 'eastern', 'airline']
# ['bought', 'tix', 'atx', 'dallas', 'route', 'thanks', 'adding', 'love', 'yr', 'airline', 'amp', 'yr', 'website', 'best', 'transactional', 'site', 'ever']
# ['anytime', 'sugafly']
# ['gave', 'credit', 'late', 'flight', 'flight', 'yesterday', 'great', 'service', 'wow', 'moment', 'unexpected', 'gesture']
# ['need', 'receipt', 'flight', 'change', 'send', 'one']
# ['submitted', 'status', 'match', 'request', 'back', 'still', 'heard', 'flying', 'monday', 'look', 'accelerate']
# ['safety', 'video', 'loved', 'first', 'cross', 'country', 'flight', 'livewelltraveled', 'sytycd']
# ['look', 'fat', 'look', 'yummy']
# ['brilliant', 'brisk', 'boston', 'cue', 'vx']
# ['atlantic', 'plough', 'lone', 'furrow', 'middleeast']
# ['atlantic', 'plough', 'lone', 'furrow', 'middleeast']
# ['atlantic', 'plough', 'lone', 'furrow', 'middleeast']
# ['omg', 'omg', 'nonstop', 'dallas', 'austin', 'virgin']
# ['plane', 'really', 'pretty', 'thought', 'u', 'know']
# ['flying', 'hawaii']
# ['pulling', 'hair', 'trying', 'book', 'flight', 'u', 'site', 'work', 'iphone', 'ipad', 'computer', 'help']
# ['thank']
# ['get', 'help', 'support', 'ticket', 'day', 'incident', 'thank']
# ['good', 'home', 'texas', 'moodlighting']
# ['cannot', 'even', 'open', 'laptop', 'seat', 'c', 'paid', 'premium', 'let']
# ['seat', 'c', 'cannot', 'even', 'open', 'laptop', 'paid', 'extra', 'seat']
# ['guy', 'starting', 'flight', 'end', 'month', 'guess', 'still', 'road', 'tripping', 'feb']
# ['thanks', 'needing', 'way', 'make', 'austin', 'trip', 'dca', 'come']
# ['really', 'sprint', 'thought', 'guy', 'kewl']
# ['cool', 'never', 'ur', 'plane']
# ['dollar', 'lax', 'la', 'fare']
# ['great', 'well', 'deserved']
# ['fyi', 'info', 'com', 'email', 'address', 'say', 'contact', 'password', 'reset', 'email', 'exist', 'email', 'bounce']
# ['status', 'match', 'week', 'gone', 'news', 'flt', 'next', 'week', 'hope', 'flt', 'count', 'towards', 'requirement', 'cust', 'svc', 'help']
# ['website', 'suck', 'donkey', 'dick', 'thought', 'know', 'best']
# ['still', 'develop', 'app', 'favorite', 'airline']
# ['crap', 'channel', 'pay', 'watch', 'uk', 'tv']
# ['got', 'set', 'thanks']
# ['channel', 'year']
# ['thing', 'see', 'passbook', 'virgin', 'mobile', 'mexico', 'integrate']
# ['giant', 'virgin', 'america', 'match', 'made', 'heaven']
# ['thank', 'goodness', 'also', 'see', 'friday', 'nwk', 'gt', 'sf', 'boom']
# ['come', 'iphone', 'app', 'still', 'using', 'making', 'waste', 'paper']
# ['back', 'seat', 'entertainment', 'system', 'accept', 'credit', 'card', 'apostrophe', 'surname', 'apostrophefail']
# ['vx', 'use', 'lga', 'slot', 'instead', 'today', 'adding', 'au', 'make', 'le', 'likely']
# ['helping', 'step', 'game', 'tindertips', 'tinderchamp']
# ['luv', 'ur', 'people', 'product', 'thing', 'u', 'charge', 'herbal', 'tea', 'black', 'tea', 'caffeine', 'drinker']
# ['thank', 'see', 'soon', 'excited', 'see', 'expansion', 'destination', 'spread', 'wing']
# ['announces', 'new', 'nonstop', 'connecting', 'amp', 'intro']
# ['add', 'austin', 'dallas', 'love', 'field', 'route']
# ['sad', 'learn', 'longer', 'fly', 'sfo', 'gt', 'phl', 'hope', 'return']
# ['tweet', 'cancelled', 'flight', 'chng', 'fee', 'flight', 'rebook', 'one', 'affiliate', 'afiliates']
# ['incredible', 'customer', 'service', 'ever', 'experienced', 'refreshing']
# ['see', 'virginamerica', 'come', 'philadelphia', 'phl']
# ['dreaming', 'really', 'open', 'route', 'dallas', 'austin', 'mean', 'houston', 'might', 'next']
# ['omg', 'finally']
# ['start', 'xweekly', 'flight', 'dallas', 'austin', 'apr', 'avgeek']
# ['nice', 'see', 'expanding', 'texas', 'forget', 'u', 'sandiego', 'would', 'love', 'see', 'flight']
# ['kinda', 'sucked', 'earphone', 'jack', 'work', 'flight', 'may', 'want', 'look', 'future', 'passenger']
# ['poor', 'experience', 'first', 'computer', 'problem', 'seat', 'malfunction', 'stuck', 'missing', 'meeting', 'san', 'diego']
# ['thankyou', 'dal', 'au', 'route', 'make', 'day']
# ['awesome', 'deal', 'dal', 'au', 'way']
# ['miss', 'nerdbird', 'san', 'jose']
# ['love', 'taking', 'backyard', 'consumer', 'win', 'biz', 'competes']
# ['flying', 'love', 'austin', 'excellent', 'news']
# ['make', 'every', 'vx', 'plane', 'nerdbird', 'austin', 'one', 'getting', 'nerd', 'love']
# ['please', 'add', 'frequency', 'pdx', 'portland']
# ['congrats', 'vx', 'new', 'route']
# ['tried', 'offered', 'charge', 'additional', 'k', 'new', 'ticket', 'stranded', 'thurs', 'st', 'time', 'last', 'time']
# ['u', 'help', 'flight', 'get', 'old', 'battling', 'cancer', 'need', 'treatment']
# ['never', 'bad', 'experience', 'one', 'took', 'cake', 'extortion', 'carry', 'item', 'well']
# ['spend', 'hour', 'worrying', 'item', 'carryon', 'would', 'broken', 'stolen', 'since', 'carry', 'plane', 'lock', 'bag']
# ['group', 'e', 'told', 'room', 'bin', 'got', 'plane', 'room', 'least', 'bag', 'row']
# ['thanks', 'making', 'flight', 'lax', 'jfk', 'nightmare', 'forcing', 'check', 'carry', 'bag', 'gate']
# ['lot', 'flight', 'book', 'site', 'working', 'phone', 'waiting', 'minute']
# ['flight', 'artisanal', 'cheese', 'wine', 'pairing']
# ['virgin', 'america', 'fly', 'direct', 'seattle', 'nyc', 'boston']
# ['classy']
# ['sure', 'lot', 'jfk', 'lhr', 'flight', 'go', 'lot', 'faster', 'mph', 'strong', 'tailwind']
# ['minus', 'minute', 'elevate', 'silver', 'upgrade', 'window', 'open', 'freeneversucks']
# ['save', 'tomorrow']
# ['taking', 'year', 'fly', 'home', 'dallas', 'get', 'shit', 'together']
# ['club', 'virgin', 'bumping', 'new', 'york']
# ['would', 'rough', 'trip', 'luckily', 'virginamerica', 'flight', 'weather']
# ['thestarter']
# ['please', 'come', 'minneapolis', 'st', 'paul']
# ['yes', 'fyi', 'bff']
# ['another', 'perfect', 'flight', 'come', 'plane', 'sun', 'visor', 'stay', 'carrier', 'make', 'raise']
# ['nice', 'rt', 'man', 'steel', 'might', 'faster', 'wifi', 'saying', 'sciencebehindtheexperience']
# ['love', 'dancing', 'little', 'richard', 'cool', 'bean']
# ['use', 'passbook', 'still', 'love', 'though', 'lt', 'use', 'email', 'future']
# ['thanks', 'free', 'birthday', 'point', 'right']
# ['application', 'io', 'looking', 'saw', 'virgin', 'mexico', 'lt']
# ['man', 'steel', 'fly', 'city', 'though', 'frequency']
# ['thanks', 'much', 'sharing', 'added', 'site']
# ['good', 'point']
# ['heard', 'virgin', 'mobile', 'hotspot']
# ['got', 'cheese', 'plate', 'flight']
# ['flight']
# ['dad', 'segway', 'best', 'part', 'whole', 'infographic']
# ['plan', 'short', 'haul', 'airline', 'europe', 'would', 'defiantly', 'fly', 'guy']
# ['wifi', 'better', 'seating']
# ['come', 'abc', 'one', 'network', 'channel']
# ['started', 'flight', 'scolding', 'using', 'overhead', 'bin', 'offered', 'person', 'seated', 'next']
# ['great', 'return', 'call', 'day', 'ask', 'myvxexperience']
# ['airline', 'cancelled', 'flighting', 'flight', 'bos', 'helping', 'customer', 'get', 'home', 'virgin', 'saying', 'good', 'luck']
# ['dear', 'virgin', 'customer', 'stranded', 'sf', 'day', 'amp', 'cost', 'least', 'accommodate']
# ['use', 'next', 'airline', 'commercial', 'lol']
# ['grouping', 'virgin', 'others', 'bos', 'weather', 'exposed', 'actual', 'cu', 'serv', 'model', 'never', 'flight', 'booking', 'problem', 'virgin']
# ['one', 'traveler', 'affected', 'boston', 'storm', 'shocked', 'virgin', 'complete', 'apathy', 'toward', 'customer']
# ['umm', 'reason', 'someone', 'different', 'contact', 'contact', 'get', 'definitive', 'answer']
# ['trying', 'make', 'change', 'advance', 'hour', 'prior', 'tried', 'online', 'earlier', 'wanted', 'change', 'fee']
# ['loyal', 'driving', 'nyc', 'pa', 'fly', 'virgin', 'since', 'cut', 'philly', 'flight']
# ['way', 'change', 'main', 'cabin', 'main', 'cabin', 'select', 'flight', 'without', 'paying', 'change', 'fee', 'penalty']
# ['guy', 'perfect', 'always', 'lt', 'wervirgin']
# ['thanks', 'best', 'customer', 'service', 'left', 'industry']
# ['give', 'silver', 'status', 'month']
# ['really', 'wish', 'fly', 'fargo', 'fare', 'amazings']
# ['mood', 'lighting', 'point', 'reclining', 'seat', 'kickin', 'foot']
# ['flight', 'scheduled', 'pm', 'departure', 'still', 'say', 'time', 'plane', 'gate', 'update', 'long', 'delay']
# ['group', 'got', 'cancelled', 'flightlation', 'fee', 'waived', 'ticket', 'booked', 'rep', 'help', 'either']
# ['sign', 'bonus', 'enroll', 'elevate']
# ['got', 'pm', 'newark', 'home', 'la', 'folk', 'ewr', 'incredible', 'letsgohome']
# ['morning', 'question', 'regarding', 'elevate', 'point', 'amp', 'flight', 'dm']
# ['still', 'waiting', 'see']
# ['wondering', 'guy', 'recieved', 'dm', 'able', 'potentially', 'respond', 'asap']
# ['flying', 'lax', 'sfo', 'looking', 'awesome', 'movie', 'lineup', 'actually', 'wish', 'long', 'haul']
# ['book', 'town', 'fare', 'way', 'restr']
# ['thanks']
# ['thanks', 'taking', 'care', 'mr', 'happy', 'customer']
# ['still', 'refund', 'word', 'via', 'dm', 'please', 'resolve', 'issue', 'cancelled', 'flightled', 'flight', 'useless', 'assistant', 'trip']
# ['delayed', 'due', 'lack', 'crew', 'delayed', 'long', 'line', 'deicing', 'still', 'need', 'improve', 'service', 'united']
# ['thanks', 'filled', 'luck', 'common']
# ['eri', 'ord', 'express', 'connection', 'hugely', 'popular', 'could', 'eri', 'ewr', 'hop']
# ['even', 'international', 'flight', 'glasgow', 'u', 'orlando', 'newark', 'min']
# ['think', 'boarded', 'flight', 'au', 'early', 'think']
# ['understand', 'tough', 'way', 'get', 'airport', 'w', 'serious', 'risk', 'accident', 'steep', 'price']
# ['gate', 'agent', 'hooked', 'alternate', 'flight', 'way', 'prevent', 'constant', 'issue', 'would', 'rock']
# ['flying', 'gla', 'mco', 'week', 'long', 'airport', 'departure', 'international', 'domestic', 'ta']
# ['thanks']
# ['thanks', 'ticket']
# ['law', 'policy']
# ['worst', 'nonrefundable', 'first', 'class', 'ticket', 'oh', 'select', 'global', 'fc', 'system', 'auto', 'selects', 'economy', 'w', 'upgrade']
# ['buy', 'tix', 'day', 'flight', 'transfer', 'tix', 'flawed', 'security', 'logic', 'flawed', 'customer', 'service']
# ['start', 'claim', 'week', 'unrealistic', 'really', 'supposed', 'go', 'long', 'car', 'seat', 'child', 'ridiculous']
# ['follow', 'please', 'airline', 'beautifull']
# ['sure', 'united', 'info', 'system']
# ['car', 'seat', 'lost', 'reimburse', 'new', 'one', 'pair', 'shoe', 'necessity', 'child']
# ['submitted', 'response', 'link', 'sent']
# ['yes', 'david', 'allan', 'send', 'email', 'number', 'kmm', 'v', 'l', 'km', 'case']
# ['totally', 'suck', 'cousin', 'worked', 'phl', 'said']
# ['wanted', 'let', 'know', 'wonderful', 'rosetta', 'gate', 'agent', 'working', 'flight', 'dan', 'ase', 'let', 'know', 'wasappreciated']
# ['yes', 'paper', 'voucher', 'got', 'january', 'th']
# ['beginning', 'feb', 'called', 'united', 'said', 'would', 'send', 'another', 'voucher', 'mail', 'never', 'got', 'anything', 'tiredofwaiting']
# ['internet', 'great', 'thing', 'emailing', 'executive', 'company', 'maybe', 'respond', 'timely', 'manner']
# ['need', 'use', 'chase', 'united', 'club', 'pas', 'yr', 'old', 'son', 'come', 'pas']
# ['suppose', 'number']
# ['flew', 'back', 'w', 'company', 'since', 'united', 'didnt', 'earlier', 'flight']
# ['lost', 'voucher', 'given', 'miami', 'aeroport', 'jan', 'use']
# ['trying', 'book', 'award', 'september', 'need', 'flight', 'show', 'even', 'w', 'many', 'award', 'seat', 'availab']
# ['sure', 'drive', 'total', 'hour', 'get', 'bag', 'like', 'explain', 'debacle', 'one', 'want', 'talk']
# ['gee', 'like', 'almost', 'caring', 'ppl', 'think', 'int', 'trusted', 'adult', 'w', 'daughter']
# ['see', 'told', 'repeatedly', 'pilot', 'late', 'flight', 'kept', 'getting', 'late', 'flightr', 'boarded', 'defibrillator', 'issue']
# ['preferred', 'security', 'line', 'anymore', 'tsa', 'pre', 'check', 'pull', 'partner', 'flight', 'platinum', 'spoiled']
# ['newarkliberty', 'airport', 'need', 'indicate', 'different', 'gate', 'terminal', 'amp', 'c', 'flyingainteasy']
# ['yes', 'please', 'newly', 'married', 'trying', 'update', 'last', 'name', 'preexisting', 'international', 'flight', 'seems', 'easy']
# ['united', 'refuse', 'reissue', 'lost', 'voucher', 'plane', 'take', 'due', 'mechanic', 'badcustomerservice']
# ['also', 'run', 'instructed', 'shattered', 'computer']
# ['yes', 'agent', 'last', 'minute', 'one', 'agent', 'rude', 'thankfully', 'ladan', 'nice']
# ['right', 'overnight', 'miami']
# ['client', 'hr', 'layover', 'iah', 'day', 'claim', 'amp', 'recheck', 'luggage', 'taken', 'care']
# ['trying', 'find', 'loaner', 'seat', 'new', 'used', 'used', 'car', 'seat', 'illegal', 'according', 'safety', 'regulation']
# ['dmed', 'detail']
# ['iah', 'charlotte', 'baggage', 'claim', 'rep', 'latrice', 'h', 'customerservice', 'non', 'existent', 'ignored', 'customer', 'inappropriately', 'touched', 'customer']
# ['kewl', 'also', 'let', 'know', 'overhead', 'bin', 'row', 'inop', 'love', 'good', 'abbreve']
# ['thanks', 'help', 'got', 'need', 'issue', 'guess', 'sit', 'awhile', 'longer']
# ['would', 'loved', 'respond', 'website', 'saw', 'really', 'long', 'form', 'business', 'new', 'seat', 'bad']
# ['refund', 'flight', 'voucher', 'another', 'flight', 'different', 'airline', 'expense', 'today', 'hour', 'drive', 'inconvenient']
# ['received', 'call', 'back', 'day', 'infant', 'car', 'seat', 'supposed', 'go', 'anywhere', 'child']
# ['thanks', 'concern', 'contact', 'customer', 'care', 'upon', 'return', 'australia']
# ['well', 'sitting', 'ground', 'time', 'waiting', 'gate', 'tiredofthis']
# ['need', 'guy', 'book', 'plane', 'concern', 'travel', 'someone', 'else', 'moving', 'forward']
# ['measly', 'e', 'certificate', 'appreciate', 'loyal', 'customer', 'wait', 'hr', 'tarmac', 'ua', 'unacceptable']
# ['email', 'address', 'username', 'sign', 'available']
# ['thank', 'able', 'claim', 'interim', 'expense', 'cost', 'stuff']
# ['rude', 'rude']
# ['get', 'boarding', 'pas', 'austrian', 'airline', 'codeshare', 'flight', 'rebook', 'incls', 'hour', 'layover', 'amp', 'stuck', 'outside', 'sec']
# ['received', 'flight', 'united', 'truly', 'break', 'guitar', 'unitedbreaksguitars', 'wantmymoneyback']
# ['flew', 'telaviv', 'paid', 'third', 'suitcase', 'even', 'make', 'plane', 'besides', 'impolite', 'service']
# ['bag', 'still', 'colo', 'spring', 'disabled', 'search', 'unfamiliar', 'airport', 'look', 'bag', 'good', 'outcome']
# ['shame', 'flex', 'ticket', 'transfer', 'rule', 'even', 'calling', 'neurosurgery', 'icu', 'enough']
# ['denver', 'said', 'handle', 'baggage', 'made', 'colo', 'spring', 'gave', 'number', 'call', 'help', 'either']
# ['guy', 'need', 'serious', 'training', 'customer', 'service', 'many', 'better', 'option', 'put', 'way', 'guy', 'handle', 'ur', 'mistake']
# ['ord', 'dca']
# ['found', 'problem', 'avoided', 'like', 'plague', 'told', 'find', 'supervisor']
# ['zcc', 'u', 'cancelled', 'flight', 'flight', 'h', 'advance', 'need', 'connect', 'flight', 'reschedule', 'link', 'helping', 'help', 'gf', 'waited', 'month', 'see']
# ['flying']
# ['addition', 'first', 'flight', 'delayed', 'hour', 'arriving', 'destination', 'hr', 'late', 'flight']
# ['cancelled', 'flighted', 'flight', 'rebook', 'u', 'added', 'flight', 'drive', 'denver', 'kc', 'thanks']
# ['announcement', 'pre', 'boarding', 'address', 'mobility', 'disability', 'requires', 'travel', 'lot', 'stuff', 'preboard']
# ['flew', 'united', 'last', 'month', 'experience', 'awesome']
# ['travel', 'booked', 'thru', 'united', 'group', 'dept', 'okc', 'ticket', 'agent', 'le', 'willing', 'help', 'connection', 'lax']
# ['v', 'upset', 'disability', 'service', 'told', 'one', 'employee', 'carrying', 'medical', 'equipment', 'rude']
# ['thnx', 'quick', 'reply', 'think', 'assist', 'intl', 'grp', 'put', 'considerable', 'inconvenience', 'today']
# ['wont', 'transfer', 'flight', 'ticket', 'accompany', 'yr', 'old', 'active', 'military', 'mom', 'emergency', 'brain', 'surgery', 'wow']
# ['week', 'late', 'flightr', 'still', 'received', 'mile', 'mileageplus', 'gift', 'card', 'starbucks', 'card', 'handed']
# ['k', 'always', 'hoping', 'improvement']
# ['yet', 'complained', 'guy', 'checked', 'luggage', 'throwing', 'bag', 'around', 'unfortunate', 'coincidence', 'hope']
# ['okc', 'ticket', 'agent', 'roger', 'mclarren', 'sp', 'le', 'helpful', 'intl', 'group', 'travel', 'problem', 'find', 'supervisor', 'help']
# ['mobile', 'apps', 'need', 'construction', 'ground', 'o', 'category', 'expensive', 'get', 'right']
# ['another', 'fail', 'united', 'ticket', 'agent', 'okc', 'le', 'helpful', 'could', 'care', 'le', 'problem', 'american', 'come']
# ['also', 'working', 'wc', 'coach', 'good', 'thing', 'bird', 'landed', 'ahead', 'schedule', 'use', 'wc', 'stat']
# ['o', 'controlled', 'rather', 'app', 'new']
# ['sent', 'email', 'customer', 'care', 'telling', 'may', 'break', 'sincerely', 'hope', 'help']
# ['silly', 'flying', 'delta', 'today', 'united', 'club', 'staff', 'attendant', 'surly', 'unhelpful', 'always', 'seem', 'bothered', 'pesky', 'folk']
# ['phone', 'number', 'find', 'call', 'flight', 'reservation']
# ['well', 'fix', 'missing', 'buddy', 'th', 'bday', 'negligence', 'attempt', 'make']
# ['believe', 'help', 'customer', 'service', 'like', 'said', 'want', 'number', 'someone', 'fix']
# ['helped', 'baggage', 'service', 'desk', 'said', 'bc', 'tsa', 'screening', 'fll', 'bag', 'made', 'bag', 'ewr']
# ['mobile', 'boarding', 'pas', 'disappeared', 'phone', 'standing', 'line', 'board', 'second', 'time', 'week', 'hmm']
# ['record', 'rozana', 'newark', 'lovely', 'helpful', 'choosekind']
# ['last', 'night', 'ord', 'lga']
# ['thx', 'update']
# ['thank']
# ['dm', 'nut']
# ['explain', 'eager', 'flight', 'attendant', 'trying', 'ask', 'vision', 'guide', 'dog']
# ['point', 'asking', 'detail', 'servicedog', 'book', 'flight', 'crew', 'read', 'continued']
# ['tried', 'one', 'available', 'bogota', 'everyone', 'rude', 'houston', 'stuck', 'hour', 'guy']
# ['worst', 'unitedflightsever', 'ua', 'la', 'iad', 'mechanical', 'problem', 'took', 'land', 'fix', 'delayed', 'wtfodds']
# ['despite', 'bag', 'making', 'newark', 'good', 'informative', 'email', 'tracking', 'update', 'help']
# ['going', 'ua', 'outbound', 'flight', 'last', 'thurs', 'delayed', 'hr', 'long', 'delay', 'worst', 'unitedflightsever']
# ['worst', 'unitedflightsever', 'ua', 'iad', 'la', 'mechanical', 'problem', 'switched', 'aircraft', 'delayed', 'hour']
# ['crashed', 'trying', 'check']
# ['wow', 'deal', 'plus', 'seat', 'available', 'easy', 'change', 'make', 'customer', 'happy']
# ['thanks', 'info', 'already', 'knew']
# ['airline', 'trouble', 'winter', 'amp', 'getting', 'good', 'customer', 'service', 'contact', 'negotiate', 'resolution']
# ['logan', 'boarding', 'gong', 'show', 'due', 'lax', 'carry', 'enforcement', 'bin', 'full', 'coat', 'room', 'bag', 'u', 'need', 'better', 'system']
# ['thank']
# ['blackmailed', 'paying', 'extra', 'return', 'ticket', 'nullified', 'san', 'francisco', 'airport', 'terrible', 'service', 'rep', 'scam']
# ['email', 'address', 'reach', 'long', 'dm']
# ['disappointed', 'u', 'didnt', 'honor', 'credit', 'given', 'ur', 'mistake', 'taking', 'business', 'elsewhere']
# ['ua', 'still', 'waiting', 'supposed', 'depart']
# ['credit', 'last', 'trip', 'never', 'came', 'mail']
# ['ok', 'month', 'waiting', 'hear', 'airline', 'gave', 'quite', 'bit', 'day', 'requested', 'terrible', 'service']
# ['process', 'ever', 'end', 'still', 'waiting', 'reply', 'since', 'month', 'pathetic', 'customerservice']
# ['going', 'website', 'flight', 'booking', 'problem', 'three', 'ticket', 'today', 'booted', 'system', 'umpteen', 'time']
# ['get', 'account', 'number', 'website', 'say', 'email', 'unavailable']
# ['need', 'book', 'two', 'one', 'way', 'order', 'fly', 'unaccompanied', 'minor']
# ['received', 'bag', 'last', 'night', 'still', 'missing', 'one']
# ['need', 'upgrade', 'seat', 'even', 'economy', 'plus', 'like', 'sitting', 'concrete', 'bench']
# ['pls', 'help', 'baby', 'hannah', 'get', 'life', 'saving', 'surgery', 'requires', 'need', 'help', 'pls', 'donate', 'rt']
# ['bet', 'wont', 'honour', 'like', 'mine', 'ey']
# ['nd', 'flight', 'also', 'delayed', 'pilot', 'boarded', 'sit', 'scheduling']
# ['guess', 'much', 'ask', 'huh']
# ['hard', 'stay', 'upset', 'someone', 'least', 'try', 'show', 'remorse']
# ['way', 'simple', 'apology', 'go', 'long', 'way', 'even', 'hollow', 'one', 'obvious', 'care', 'well']
# ...
# ['received', 'luggage', 'also', 'looked', 'left', 'snow', 'arrived', 'asking', 'people', 'refunded']
# ['updated', 'aircraft', 'wifi', 'device', 'entertainment', 'outlet', 'get', 'charge', 'device']
# ['one', 'scan', 'inside', 'plane', 'asked', 'people', 'line', 'around', 'plane', 'going']
# ['gate', 'change', 'two', 'delay', 'even', 'crew', 'think', 'airline', 'suck']
# ['frustrated', 'wasted', 'day', 'due', 'equipment', 'failure']
# ['computer', 'stopped', 'giving', 'update', 'took', 'flight', 'info', 'app', 'ridiculous', 'keep', 'people', 'updated']
# ['soooo', 'day', 'offered', 'response', 'assume', 'poor', 'treatment', 'gate', 'agent', 'norm']
# ['terrific', 'many', 'thanks', 'looking', 'forward', 'back', 'ua', 'tomorrow', 'great', 'flight', 'vancouver']
# ['call', 'resulted', 'hr', 'hold', 'time', 'amp', 'day', 'wait', 'check', 'suspect', 'code', 'share', 'fare', 'nothing', 'investigated', 'time', 'wasted']
# ['taken', 'week', 'cust', 'care', 'respond', 'case', 'requesting', 'refund', 'wi', 'fi', 'working', 'get', 'update']
# ['appreciate', 'effort', 'getting', 'home']
# ['correct', 'spent', 'hour', 'trying', 'book', 'online', 'receive', 'error', 'clicking', 'final', 'purchase', 'button']
# ['today', 'finest', 'could', 'prevented', 'one', 'gate', 'agent', 'advising', 'passenger']
# ['real', 'deal', 'delay', 'flight', 'ua', 'denver', 'vega']
# ['ua', 'madrid', 'arrived', 'agent', 'mass', 'confusion', 'sent', 'fro', 'ua', 'employee', 'maryjo', 'rude', 'unhelpful']
# ['system', 'failure', 'bad', 'trend', 'software', 'project', 'like', 'flying', 'airplane', 'thing', 'emergency', 'takeoff']
# ['lot', 'report', 'system', 'failure', 'delaying', 'flight', 'last', 'week', 'currently', 'sitting', 'tarmac', 'ogg', 'hour']
# ['rebooting', 'chicago', 'dispatch', 'system', 'need', 'tired', 'sitting', 'plane']
# ['despite', 'shaky', 'connection', 'look', 'like', 'get', 'home', 'tonight', 'great', 'job', 'touch', 'go']
# ['however', 'completely', 'control', 'price', 'still', 'displayed']
# ['aircraft', 'closest', 'gate', 'flight', 'one', 'closest', 'gate', 'going', 'chicago']
# ['tell', 'file', 'claim', 'clothing', 'purchased']
# ['comically', 'return', 'flight', 'ase', 'two', 'united', 'flight', 'boarding', 'adjacent', 'gate', 'clear', 'plane', 'board']
# ['grk', 'file', 'reference']
# ['would', 'contact', 'discus', 'poor', 'experience', 'customer', 'service', 'would', 'give', 'shot']
# ['ua', 'pacific', 'rim', 'date', 'night', 'cut', 'constantly', 'randomly', 'one', 'spot', 'repeatably']
# ['trying', 'since', 'file', 'report']
# ['send', 'email', 'bad', 'experience', 'send', 'back', 'generic', 'response', 'yet', 'another', 'reason', 'never', 'fly']
# ['mom', 'left', 'kindle', 'flight', 'today', 'burgundy', 'case', 'light', 'seat', 'anyone', 'find']
# ['ticket', 'please', 'refund', 'unnecessary', 'upgrade', 'fee']
# ['horrible', 'lost', 'carseat', 'expect', 'u', 'use', 'loner', 'carseat', 'safety', 'regulation', 'say', 'illegal', 'use', 'used', 'car', 'seat']
# ['thank']
# ['decision', 'decision', 'love', 'try', 'service', 'offer', 'status', 'match', 'kp']
# ['need', 'info', 'great', 'amenity', 'kit', 'pj', 'included', 'status', 'match', 'aa', 'kp']
# ['care', 'link', 'showed', 'wrong', 'price', 'site', 'site', 'amp', 'responsibility', 'ensure', 'correctness']
# ['flight', 'lie', 'flat', 'seating', 'stl', 'pdx', 'around', 'date', 'march']
# ['need', 'get', 'home', 'th', 'telling', 'th', 'night', 'compensation', 'anything', 'done']
# ['baggage', 'fee', 'waived', 'premier', 'member', 'please', 'see', 'jp', 'point', 'membership']
# ['wonderful', 'bag', 'claim', 'people', 'finally', 'bag', 'catch', 'earlier', 'flight', 'original', 'flight', 'landed', 'wastedtime']
# ['dmed', 'thank']
# ['thanks', 'touch']
# ['thanks', 'karen', 'salisbury', 'iah', 'amazing', 'customer', 'service', 'found', 'daughter', 'bag', 'lost', 'ua', 'made', 'day']
# ['day', 'late', 'flightr', 'bag', 'left', 'iad', 'united', 'helping', 'everyone', 'tell', 'different', 'story']
# ['hi', 'direct', 'flight', 'houston', 'reno', 'begin', 'see', 'day', 'march']
# ['like', 'continental', 'chicken', 'feat', 'fair']
# ['assist', 'current', 'flight', 'status', 'flt', 'dfw', 'tomorrow']
# ['left', 'comment', 'customer', 'care', 'thanks', 'contacting']
# ['lose', 'gate', 'checked', 'bag', 'den', 'ord', 'direct', 'flight', 'ugh']
# ['caught', 'earlier', 'flight', 'ord', 'gate', 'checked', 'bag', 'lost', 'hare', 'original', 'flight', 'land', 'minute', 'frustrating']
# ['yes', 'thanks', 'much', 'see', 'spoke', 'reservation', 'team', 'reinstated', 'flight', 'thanks', 'ey']
# ['captain', 'behalf', 'front', 'office', 'welcome', 'board', 'never', 'heard', 'laughed', 'hard', 'funnycaptain']
# ['please', 'follow', 'dm', 'missing', 'bag']
# ['clear', 'luggage', 'comment', 'referencing', 'photo', 'attached', 'flight', 'jac']
# ['great', 'fare']
# ['left', 'item', 'plane', 'calling', 'non', 'stop', 'one', 'answering', 'please', 'help']
# ['awesome', 'book', 'next', 'christmas', 'vacatinn', 'december', 'way', 'want', 'devalue', 'mileage', 'plus']
# ['good', 'number', 'call', 'speak', 'someone', 'fix', 'people', 'luggage', 'saturday']
# ['thank', 'u', 'secured', 'room', 'night', 'thx', 'helpful', 'customer', 'service', 'rep', 'n', 'dorns', 'thanked', 'u', 'goodenoughmother']
# ['damn', 'bag']
# ['well', 'someone', 'tell', 'employee', 'denver', 'baggage', 'claim', 'still', 'bag']
# ['greeting', 'ua', 'club', 'member', 'idea', 'use', 'air', 'canada', 'lounge', 'yvr', 'flying', 'ua', 'tomorrow']
# ['mexico', 'international', 'u']
# ['diverted', 'missed', 'connecting', 'flight', 'told', 'bag', 'way', 'msy', 'people', 'cared']
# ['male', 'agnt', 'la', 'threatens', 'canadian', 'cust', 'cust', 'take', 'pic', 'gate', 'agent', 'announce', 'help', 'rebook', 'friendlyskies']
# ['want', 'go', 'home', 'tonight', 'cancelled', 'flight', 'last', 'leg', 'reserv', 'w', 'permission', 'ph', 'rps']
# ['stressed', 'rude', 'agent', 'overwhelmed', 'delyd', 'flight', 'la', 'den', 'yelling', 'several', 'people', 'pretty', 'friendlyskies']
# ['landed', 'boston', 'last', 'night', 'hour', 'traveling', 'rough', 'tho']
# ['fail', 'cancelled', 'flightled', 'flight', 'frm', 'gjt', 'used', 'reserv', 'home', 'iah', 'sea', 'reflight', 'booking', 'problem', 'w', 'permission', 'ph', 'rps']
# ['sent', 'thank', 'u', 'rt', 'please', 'dm', 'confirmation', 'number', 'reflight', 'booking', 'problem', 'needed', 'thank', 'ey']
# ['made', 'fly', 'list', 'airline', 'wait', 'connector', 'late', 'flight', 'stuck', 'iah']
# ['deal', 'u', 'provide', 'voucher', 'overnight', 'cozy', 'floor', 'ohare', 'gross', 'helpmeplease', 'anyonethere']
# ['also', 'mere', 'fact', 'go', 'online', 'issue', 'statement', 'vice', 'calling', 'talking', 'directly', 'one', 'good', 'example']
# ['thank', 'flew', 'newark', 'vail', 'eagle']
# ['weekend', 'dealing', 'company', 'would', 'say', 'otherwise']
# ['flight', 'gone', 'got', 'plane', 'businesstravel', 'goodenoughmother']
# ['proper', 'response', 'sorry', 'wait', 'flight', 'look', 'issue', 'would', 'handle']
# ['customer', 'service', 'terrible', 'stood', 'inline', 'hour', 'flight', 'hour', 'late', 'flightr', 'still', 'bag', 'disgutedindenver']
# ['please', 'upload', 'march', 'demand', 'entertainment', 'listing', 'website']
# ['inadequate', 'accident']
# ['denver', 'international', 'airport']
# ['thank', 'responding', 'quickly', 'helpful', 'tool']
# ['boarding', 'time', 'show', 'min', 'gate', 'agent', 'started', 'showed', 'check', 'bag']
# ['agent', 'la', 'letting', 'customer', 'know', 'help', 'rebook', 'delayed', 'flight', 'den', 'unfriendlyskies']
# ['empathizes', 'w', 'disappointment', 'stclass', 'flight', 'w', 'nonworking', 'entertainmnt', 'worth', 'unfriendlyskies']
# ['work']
# ['seen', 'message', 'today', 'mcdonnell', 'douglas', 'dc', 'model', 'hear', 'read', 'goodnight']
# ['searched', 'mileage', 'ticket', 'bom', 'find', 'single', 'one', 'saver', 'award', 'see', 'play', 'earn', 'mile', 'use']
# ['flight', 'arrives', 'minute', 'early', 'wait', 'hour', 'bag']
# ['issue', 'fact', 'one', 'even', 'called', 'despite', 'promise', 'confirm', 'bag', 'location']
# ['girl', 'gotta', 'get', 'flight', 'name', 'change', 'bought', 'one', 'mean', 'ex', 'boyfriend', 'need', 'girl', 'trip', 'stat']
# ['thank', 'signed', 'notification', 'shall', 'watch', 'wait']
# ['still', 'waiting', 'hear', 'back', 'wallet', 'stolen', 'one', 'plane', 'would', 'appreciate', 'resolution']
# ['would', 'love', 'someone', 'could', 'get', 'back', 'austin', 'tonight', 'wish', 'wait', 'til', 'tomorrow', 'morning']
# ['lost', 'baggage', 'heard', 'different', 'thing', 'different', 'employee', 'said', 'nothing']
# ['c', 'think', 'mile', 'repair', 'damage', 'done', 'interesting', 'travel', 'exp', 'worst', 'flight', 'ever']
# ['flight', 'dfw', 'tuesday', 'far', 'advance', 'give', 'notice', 'cancelled', 'flightled']
# ['signed', 'notification', 'first', 'trip', 'updated', 'sure', 'happened']
# ['thank', 'took', 'care', 'everything', 'made', 'right', 'experience', 'used', 'opened', 'app', 'find', 'flight', 'changed']
# ['line', 'response', 'waiting', 'tomorrow', 'morning', 'flight', 'overbooked']
# ['took', 'exact', 'aircraft', 'lax', 'day', 'ago', 'fit', 'problem', 'agent', 'today', 'told', 'nonsense', 'policy', 'change']
# ['helpful', 'agent', 'club', 'helped', 'baggage', 'fee', 'night', 'life', 'stop', 'business']
# ['never', 'heard']
# ['charge', 'ticket', 'change', 'fee', 'incur', 'mysterious', 'cost', 'incur']
# ['exhausted', 'amp', 'frustrated', 'link', 'fb', 'post', 'abt', 'travel', 'issue']
# ['denied', 'getting', 'plane', 'w', 'getting', 'chance', 'prove', 'fit', 'rookie', 'read', 'bio']
# ['exactly', 'point', 'fit', 'premier', 'access', 'boarding', 'group', 'return', 'ticket', 'yr']
# ['never', 'experienced', 'worst', 'customer', 'service', 'placing', 'blame', 'codeshare', 'partner', 'assuming', 'responsibility', 'unacceptable']
# ['currently', 'board', 'check', 'terrible', 'staff', 'rude', 'expensive', 'luggage', 'thrown', 'around', 'etc']
# ['fucked', 'voided', 'ticket', 'kept', 'money', 'even', 'apology', 'never', 'fly', 'airline', 'unitedairlines']
# ['worst', 'customer', 'svcs', 'kevin', 'rep', 'call', 'center', 'must', 'investigated', 'baggage', 'lost', 'help', 'argument']
# ['sell', 'ticket', 'terrible', 'service', 'ua', 'staff', 'cannot', 'reach', 'silver']
# ['got', 'demoted', 'gold', 'cuz', 'hubby', 'got', 'pqd', 'tho', 'enuf', 'spent', 'gold', 'spousal', 'discrimination', 'angry']
# ['thank']
# ['direct', 'flight', 'belfast', 'intl', 'newark', 'resume', 'winter', 'break', 'thanks']
# ['favorite', 'way', 'travel', 'thank']
# ['yes', 'awful', 'weather', 'appears', 'get', 'home']
# ['yes', 'lot', 'terrible', 'customer', 'service', 'newark', 'despite', 'raising', 'complaint', 'ignored', 'hence', 'tweet']
# ['lovely', 'new', 'plane', 'lga', 'ord', 'power', 'outlet']
# ['tweet', 'id', 'number', 'reveal', 'home', 'address', 'anyone', 'web']
# ['filed', 'delayed', 'bag', 'report', 'saturday', 'flight', 'cancelled', 'flightled', 'never', 'went', 'anywhere']
# ['person', 'currently', 'bettween', 'gate', 'lax']
# ['need', 'land', 'ewr', 'baggage', 'claim', 'file', 'sent', 'employee', 'droppeditoffyet']
# ['rarely', 'cease', 'amaze', 'worse', 'hope', 'last', 'time', 'fly']
# ['thank', 'quick', 'response', 'cannot', 'dm', 'follow', 'well']
# ['icloud', 'yet', 'please', 'help']
# ['need', 'phone', 'number', 'baggage', 'claim', 'lax', 'mom', 'left', 'phone', 'someone', 'called', 'saying', 'would', 'put']
# ['response', 'back']
# ['atrocious', 'customer', 'service']
# ['albanyairport', 'delayed', 'departure', 'check', 'bag', 'gate', 'claiming', 'space', 'filled', 'walk', 'open', 'space', 'delay', 'poorcustomerservice']
# ['cancelled', 'flighted', 'flight', 'reason', 'amp', 'phone', 'hour', 'vacation']
# ['response', 'shaking', 'head', 'back', 'forth', 'tsk', 'better', 'customer', 'service', 'apology']
# ['thanks', 'k', 'mile', 'rtb', 'europe', 'multiple', 'destination', 'could', 'stop', 'u', 'way', 'way', 'back', 'mileage', 'diff']
# ['course', 'bag', 'frustrated']
# ['worst', 'avoid', 'like', 'plague']
# ['worst', 'airline', 'world']
# ['someone', 'need', 'dm', 'resolve', 'correctly', 'extremely', 'disappointed', 'service', 'received', 'terrible', 'management']
# ['premier', 'gold', 'desk', 'change', 'flight', 'waif', 'fee', 'give', 'wrong', 'flight', 'jana', 'acosta', 'salt', 'lake', 'refuse', 'service', 'angry']
# ['give', 'one', 'thing', 'consistent', 'unfortunately', 'consistent', 'job', 'well', 'alwaysdelayedonunited']
# ['right', 'angry']
# ['first', 'time', 'flying', 'united', 'also', 'last', 'time', 'terrible', 'back', 'branson', 'virginatlantic', 'unitedairlines']
# ['used', 'committed', 'continentalairlines', 'flyer', 'merger', 'remember', 'switched', 'communicationfail']
# ['least', 'could', 'offer', 'ticket', 'coach', 'instead', 'cancelled', 'flighting', 'reservation', 'glitch', 'notfair']
# ['saying', 'made', 'flight', 'poor', 'non', 'communication', 'unaccounted', 'lost', 'time', 'amp', 'lot', 'frustrated', 'flyer', 'standing', 'around']
# ['think', 'dm', 'would', 'better']
# ['gate', 'announcement', 'state', 'delay', 'due', 'maintenance', 'yet', 'app', 'say', 'late', 'flight', 'arriving', 'aircraft', 'tell', 'truth']
# ['easily', 'worst', 'company', 'ever', 'experienced', 'lost', 'someone', 'personal', 'possession', 'amp', 'care', 'le']
# ['app', 'show', 'arriving', 'aircraft', 'early', 'departing', 'flight', 'delayed', 'due', 'late', 'flight', 'arriving', 'aircraft']
# ['already', 'airport', 'hr', 'late', 'flightr', 'still', 'guy', 'really', 'killing', 'today', 'trying', 'stay', 'positive']
# ['united', 'service', 'level', 'reach', 'etihad', 'let', 'realistically', 'lufthansa', 'ill', 'consider']
# ['really', 'someone', 'called', 'sick', 'someone', 'forgot', 'call', 'replacement', 'hour', 'late', 'flight', 'take', 'theworst']
# ['asked', 'flight', 'attendant', 'typical', 'compensation', 'would', 'amp', 'say', 'might', 'get', 'free', 'tv', 'unacceptable']
# ['done']
# ['thank', 'jh', 'appreciate', 'prompt', 'response', 'passenger']
# ['disappointment', 'today', 'simply', 'put', 'rather', 'unpleased', 'thing', 'currently', 'flight', 'delayed', 'cant', 'wait', 'get', 'home']
# ['round', 'trip', 'non', 'english', 'speaking', 'friend', 'stranded', 'twice', 'hour', 'time', 'staff', 'member', 'rude']
# ['found', 'group', 'people', 'actually', 'hate', 'people', 'isi', 'thats', 'right', 'united', 'airline']
# ['nope', 'walked', 'amp', 'orf', 'terminal', 'amp', 'united', 'agent', 'found', 'showed', 'last', 'minute', 'board', 'u', 'many', 'panicked', 'people']
# ['thank']
# ['time', 'finally', 'get', 'dallas', 'could', 'driven', 'le', 'frustration', 'cheaper']
# ['trying', 'get', 'final', 'destination', 'need', 'compensation', 'hr', 'personal', 'time', 'wasted']
# ['guy', 'really', 'customer', 'service', 'clue', 'could', 'spent', 'effort', 'clearing', 'bin', 'rollerboards', 'instead', 'art', 'project', 'mine']
# ['priority', 'iove']
# ['pleased', 'premier', 'platinum']
# ['put', 'bag', 'plane', 'seattle', 'flight', 'waiting', 'line', 'talk', 'someone', 'bag', 'status', 'matter']
# ['hahaha', 'american', 'company', 'would', 'say', 'great', 'sarcasm']
# ['think', 'actually', 'like', 'screen']
# ['apparently', 'asking', 'people', 'board', 'plane', 'big', 'miscalculation', 'made']
# ['shame', 'choosing', 'united', 'may', 'difference', 'reuniting', 'aging', 'friend', 'never', 'seeing', 'poorservice']
# ['hi', 'guy', 'general', 'enquires', 'email', 'address', 'please', 'thanks', 'david']
# ['checking', 'status', 'claim', 'going', 'month', 'attention', 'upset']
# ['flight', 'delayed', 'due', 'maintenance', 'lit', 'caused', 'miss', 'connection', 'iah', 'msy', 'help']
# ['unitedairlines', 'pls', 'fix', 'aspenbaggagefail', 'issue', 'pay', 'way', 'aspen', 'flight', 'cancelled', 'flight', 'left', 'u', 'cold', 'den']
# ['read', 'bio', 'see', 'work', 'never', 'encountered', 'airline', 'disappointed', 'understatement']
# ['customer', 'care', 'email', 'phone', 'rep', 'speak', 'many', 'issue', 'placed', 'character']
# ['thank', 'certainly', 'take', 'look', 'please', 'follow', 'dm', 'confirmation', 'number', 'assistance', 'jh']
# ['process', 'recovering', 'car', 'rental', 'condo', 'rental', 'florida', 'called', 'united', 'alternate', 'flight', 'noanswer']

# %%
len(new_data)
# Out:
# 1000

# %% [markdown]
# ## To do : for each tweet get it sentiment using sentiwordnet
# NB : add you name and ubmit your work under Lab4_submission

# %%
for j,lemma in enumerate(new_data):
    pos_val = nltk.pos_tag(lemma)
    senti_val = [get_sentiment(x,y) for (x,y) in pos_val]
    #Aggregating Scores
    pos,neg,obj = 0,0,0
    for i in range(len(senti_val)):
        try:
            pos = pos + senti_val[i][1]
            neg = neg + senti_val[i][2]
            obj = obj + senti_val[i][3]
        
        except:
            continue
    print("Sentiment of the statement",j," is {0} ".format(pos - neg))
# Out:
# Sentiment of the statement 0  is 0.0
# Sentiment of the statement 1  is 0.0
# Sentiment of the statement 2  is 0.125
# Sentiment of the statement 3  is 0.0
# Sentiment of the statement 4  is 0.125
# Sentiment of the statement 5  is 0.25
# Sentiment of the statement 6  is 0.0
# Sentiment of the statement 7  is 0.625
# Sentiment of the statement 8  is 0.375
# Sentiment of the statement 9  is 0.5
# Sentiment of the statement 10  is 0.125
# Sentiment of the statement 11  is 0.875
# Sentiment of the statement 12  is 0.5
# Sentiment of the statement 13  is 1.0
# Sentiment of the statement 14  is 0.125
# Sentiment of the statement 15  is -0.125
# Sentiment of the statement 16  is -0.25
# Sentiment of the statement 17  is 0.5
# Sentiment of the statement 18  is 0.0
# Sentiment of the statement 19  is 1.0
# Sentiment of the statement 20  is 0.375
# Sentiment of the statement 21  is 0.625
# Sentiment of the statement 22  is 1.25
# Sentiment of the statement 23  is 0.125
# Sentiment of the statement 24  is 0.375
# Sentiment of the statement 25  is 0.25
# Sentiment of the statement 26  is -0.625
# Sentiment of the statement 27  is -0.375
# Sentiment of the statement 28  is -1.0
# Sentiment of the statement 29  is -0.375
# Sentiment of the statement 30  is -0.5
# Sentiment of the statement 31  is 0.0
# Sentiment of the statement 32  is 0.5
# Sentiment of the statement 33  is 0.375
# Sentiment of the statement 34  is 0.0
# Sentiment of the statement 35  is 0.75
# Sentiment of the statement 36  is 0.125
# Sentiment of the statement 37  is 1.25
# Sentiment of the statement 38  is 0.0
# Sentiment of the statement 39  is 0.0
# Sentiment of the statement 40  is 0.0
# Sentiment of the statement 41  is -0.25
# Sentiment of the statement 42  is 0.625
# Sentiment of the statement 43  is -0.875
# Sentiment of the statement 44  is 0.0
# Sentiment of the statement 45  is 0.75
# Sentiment of the statement 46  is 0.0
# Sentiment of the statement 47  is -0.375
# Sentiment of the statement 48  is 0.375
# Sentiment of the statement 49  is 0.125
# Sentiment of the statement 50  is 0.0
# Sentiment of the statement 51  is 0.125
# Sentiment of the statement 52  is -0.125
# Sentiment of the statement 53  is 0.5
# Sentiment of the statement 54  is 0.0
# Sentiment of the statement 55  is -1.0
# Sentiment of the statement 56  is 0.625
# Sentiment of the statement 57  is 0
# Sentiment of the statement 58  is 0
# Sentiment of the statement 59  is 0.375
# Sentiment of the statement 60  is -0.375
# Sentiment of the statement 61  is 0.625
# Sentiment of the statement 62  is 0.0
# Sentiment of the statement 63  is 0.0
# Sentiment of the statement 64  is 1.5
# Sentiment of the statement 65  is 0.625
# Sentiment of the statement 66  is 0.125
# Sentiment of the statement 67  is -0.125
# Sentiment of the statement 68  is 0.875
# Sentiment of the statement 69  is -0.625
# Sentiment of the statement 70  is -0.375
# Sentiment of the statement 71  is -0.375
# Sentiment of the statement 72  is 0.125
# Sentiment of the statement 73  is 0.75
# Sentiment of the statement 74  is -0.5
# Sentiment of the statement 75  is 1.0
# Sentiment of the statement 76  is 0.5
# Sentiment of the statement 77  is 0.75
# Sentiment of the statement 78  is 0.0
# Sentiment of the statement 79  is -0.75
# Sentiment of the statement 80  is 0.0
# Sentiment of the statement 81  is 0.625
# Sentiment of the statement 82  is 0.875
# Sentiment of the statement 83  is -0.25
# Sentiment of the statement 84  is -0.625
# Sentiment of the statement 85  is 0.375
# Sentiment of the statement 86  is -0.625
# Sentiment of the statement 87  is 0.375
# Sentiment of the statement 88  is 0.5
# Sentiment of the statement 89  is 0.0
# Sentiment of the statement 90  is 0.0
# Sentiment of the statement 91  is 0.125
# Sentiment of the statement 92  is -0.125
# Sentiment of the statement 93  is -0.375
# Sentiment of the statement 94  is 0.0
# Sentiment of the statement 95  is 0.375
# Sentiment of the statement 96  is 0.625
# Sentiment of the statement 97  is -0.375
# Sentiment of the statement 98  is -0.375
# Sentiment of the statement 99  is -0.625
# Sentiment of the statement 100  is 0.0
# Sentiment of the statement 101  is -0.875
# Sentiment of the statement 102  is 0.875
# Sentiment of the statement 103  is 0.0
# Sentiment of the statement 104  is -0.75
# Sentiment of the statement 105  is 0.5
# Sentiment of the statement 106  is 1.0
# Sentiment of the statement 107  is 0.25
# Sentiment of the statement 108  is 0.0
# Sentiment of the statement 109  is 0.125
# Sentiment of the statement 110  is 0.125
# Sentiment of the statement 111  is 0.125
# Sentiment of the statement 112  is 0.125
# Sentiment of the statement 113  is 0.0
# Sentiment of the statement 114  is -0.625
# Sentiment of the statement 115  is 0.25
# Sentiment of the statement 116  is 0.625
# Sentiment of the statement 117  is 0.375
# Sentiment of the statement 118  is 0.5
# Sentiment of the statement 119  is 0.25
# Sentiment of the statement 120  is 0.0
# Sentiment of the statement 121  is -0.75
# Sentiment of the statement 122  is 0.0
# Sentiment of the statement 123  is 0.875
# Sentiment of the statement 124  is 1.125
# Sentiment of the statement 125  is 0.875
# Sentiment of the statement 126  is 0.75
# Sentiment of the statement 127  is 1.875
# Sentiment of the statement 128  is 0.0
# Sentiment of the statement 129  is 0.0
# Sentiment of the statement 130  is -0.125
# Sentiment of the statement 131  is -1.75
# Sentiment of the statement 132  is -0.125
# Sentiment of the statement 133  is -0.375
# Sentiment of the statement 134  is -0.75
# Sentiment of the statement 135  is 0.0
# Sentiment of the statement 136  is 0.0
# Sentiment of the statement 137  is 0.0
# Sentiment of the statement 138  is 0.0
# Sentiment of the statement 139  is 0.5
# Sentiment of the statement 140  is -1.0
# Sentiment of the statement 141  is 0.5
# Sentiment of the statement 142  is 0.0
# Sentiment of the statement 143  is 0.625
# Sentiment of the statement 144  is -0.375
# Sentiment of the statement 145  is 1.125
# Sentiment of the statement 146  is 0.25
# Sentiment of the statement 147  is 0.75
# Sentiment of the statement 148  is 0.0
# Sentiment of the statement 149  is -0.875
# Sentiment of the statement 150  is 0.0
# Sentiment of the statement 151  is 0.25
# Sentiment of the statement 152  is 1.375
# Sentiment of the statement 153  is 0.0
# Sentiment of the statement 154  is 0.875
# Sentiment of the statement 155  is 0.0
# Sentiment of the statement 156  is -0.125
# Sentiment of the statement 157  is -0.625
# Sentiment of the statement 158  is 0.0
# Sentiment of the statement 159  is -0.5
# Sentiment of the statement 160  is 0.0
# Sentiment of the statement 161  is 0.5
# Sentiment of the statement 162  is -0.25
# Sentiment of the statement 163  is 0.0
# Sentiment of the statement 164  is 0.0
# Sentiment of the statement 165  is 0.5
# Sentiment of the statement 166  is 0.0
# Sentiment of the statement 167  is -0.5
# Sentiment of the statement 168  is -0.375
# Sentiment of the statement 169  is 0.0
# Sentiment of the statement 170  is -0.375
# Sentiment of the statement 171  is 0.0
# Sentiment of the statement 172  is 0.0
# Sentiment of the statement 173  is -0.25
# Sentiment of the statement 174  is -0.25
# Sentiment of the statement 175  is 0.375
# Sentiment of the statement 176  is 0
# Sentiment of the statement 177  is -1.25
# Sentiment of the statement 178  is -0.75
# Sentiment of the statement 179  is -0.625
# Sentiment of the statement 180  is 0.75
# Sentiment of the statement 181  is -0.125
# Sentiment of the statement 182  is 0.0
# Sentiment of the statement 183  is 0.125
# Sentiment of the statement 184  is 0.25
# Sentiment of the statement 185  is 0.0
# Sentiment of the statement 186  is -1.625
# Sentiment of the statement 187  is -1.125
# Sentiment of the statement 188  is 0.375
# Sentiment of the statement 189  is -0.125
# Sentiment of the statement 190  is 0.125
# Sentiment of the statement 191  is -0.5
# Sentiment of the statement 192  is 0.0
# Sentiment of the statement 193  is 0.125
# Sentiment of the statement 194  is 0.125
# Sentiment of the statement 195  is -0.875
# Sentiment of the statement 196  is 0.0
# Sentiment of the statement 197  is 0.0
# Sentiment of the statement 198  is 0.625
# Sentiment of the statement 199  is 0.5
# Sentiment of the statement 200  is 0.0
# Sentiment of the statement 201  is 0.375
# Sentiment of the statement 202  is 0.125
# Sentiment of the statement 203  is 0.125
# Sentiment of the statement 204  is 0.0
# Sentiment of the statement 205  is 0.75
# Sentiment of the statement 206  is 0.375
# Sentiment of the statement 207  is 1.125
# Sentiment of the statement 208  is 1.0
# Sentiment of the statement 209  is 0.0
# Sentiment of the statement 210  is -0.125
# Sentiment of the statement 211  is 0.125
# Sentiment of the statement 212  is -0.5
# Sentiment of the statement 213  is -0.375
# Sentiment of the statement 214  is 0.0
# Sentiment of the statement 215  is 0.0
# Sentiment of the statement 216  is 0.875
# Sentiment of the statement 217  is -0.25
# Sentiment of the statement 218  is -0.5
# Sentiment of the statement 219  is 0.25
# Sentiment of the statement 220  is 0.375
# Sentiment of the statement 221  is 0.625
# Sentiment of the statement 222  is 0.625
# Sentiment of the statement 223  is 0.0
# Sentiment of the statement 224  is 0.0
# Sentiment of the statement 225  is -0.125
# Sentiment of the statement 226  is 0
# Sentiment of the statement 227  is 0.5
# Sentiment of the statement 228  is 0.75
# Sentiment of the statement 229  is 1.125
# Sentiment of the statement 230  is 0.25
# Sentiment of the statement 231  is -0.125
# Sentiment of the statement 232  is 0.0
# Sentiment of the statement 233  is 0.25
# Sentiment of the statement 234  is 0.625
# Sentiment of the statement 235  is 0.0
# Sentiment of the statement 236  is 0.125
# Sentiment of the statement 237  is 0.375
# Sentiment of the statement 238  is 0.375
# Sentiment of the statement 239  is 0.0
# Sentiment of the statement 240  is 0.0
# Sentiment of the statement 241  is -0.75
# Sentiment of the statement 242  is 0.25
# Sentiment of the statement 243  is -0.125
# Sentiment of the statement 244  is 0.125
# Sentiment of the statement 245  is 0.5
# Sentiment of the statement 246  is 0.125
# Sentiment of the statement 247  is 0.75
# Sentiment of the statement 248  is -0.375
# Sentiment of the statement 249  is 0.625
# Sentiment of the statement 250  is 0.5
# Sentiment of the statement 251  is 0.75
# Sentiment of the statement 252  is 1.0
# Sentiment of the statement 253  is 0.875
# Sentiment of the statement 254  is 0.25
# Sentiment of the statement 255  is -0.25
# Sentiment of the statement 256  is 0.5
# Sentiment of the statement 257  is 0.125
# Sentiment of the statement 258  is 0.875
# Sentiment of the statement 259  is 0.25
# Sentiment of the statement 260  is -0.25
# Sentiment of the statement 261  is -1.0
# Sentiment of the statement 262  is -0.625
# Sentiment of the statement 263  is 0.5
# Sentiment of the statement 264  is 0.75
# Sentiment of the statement 265  is 0.625
# Sentiment of the statement 266  is 0.625
# Sentiment of the statement 267  is 0.25
# Sentiment of the statement 268  is 0.0
# Sentiment of the statement 269  is 0.625
# Sentiment of the statement 270  is 0.0
# Sentiment of the statement 271  is 0.0
# Sentiment of the statement 272  is 1.0
# Sentiment of the statement 273  is 0.375
# Sentiment of the statement 274  is 0.0
# Sentiment of the statement 275  is 0.0
# Sentiment of the statement 276  is 0.0
# Sentiment of the statement 277  is 0.25
# Sentiment of the statement 278  is -0.125
# Sentiment of the statement 279  is -0.5
# Sentiment of the statement 280  is 0
# Sentiment of the statement 281  is -0.5
# Sentiment of the statement 282  is 0.25
# Sentiment of the statement 283  is -0.625
# Sentiment of the statement 284  is 0.0
# Sentiment of the statement 285  is 0.5
# Sentiment of the statement 286  is 0.0
# Sentiment of the statement 287  is 0.125
# Sentiment of the statement 288  is -0.125
# Sentiment of the statement 289  is 0.0
# Sentiment of the statement 290  is -0.375
# Sentiment of the statement 291  is 0.125
# Sentiment of the statement 292  is 0.375
# Sentiment of the statement 293  is 0.125
# Sentiment of the statement 294  is 0.375
# Sentiment of the statement 295  is 0.75
# Sentiment of the statement 296  is 0.5
# Sentiment of the statement 297  is 0.0
# Sentiment of the statement 298  is 0.0
# Sentiment of the statement 299  is 0.5
# Sentiment of the statement 300  is 0.0
# Sentiment of the statement 301  is -0.625
# Sentiment of the statement 302  is 0.625
# Sentiment of the statement 303  is -0.375
# Sentiment of the statement 304  is -0.25
# Sentiment of the statement 305  is 0.75
# Sentiment of the statement 306  is -0.625
# Sentiment of the statement 307  is 1.0
# Sentiment of the statement 308  is 0.875
# Sentiment of the statement 309  is 0.125
# Sentiment of the statement 310  is 0.0
# Sentiment of the statement 311  is 0.125
# Sentiment of the statement 312  is 0.5
# Sentiment of the statement 313  is 0.5
# Sentiment of the statement 314  is 0.125
# Sentiment of the statement 315  is 0.0
# Sentiment of the statement 316  is 0.0
# Sentiment of the statement 317  is 0.25
# Sentiment of the statement 318  is 0.0
# Sentiment of the statement 319  is -0.125
# Sentiment of the statement 320  is 0.0
# Sentiment of the statement 321  is 0.0
# Sentiment of the statement 322  is 0.75
# Sentiment of the statement 323  is 0.125
# Sentiment of the statement 324  is 0.875
# Sentiment of the statement 325  is 1.25
# Sentiment of the statement 326  is 0.5
# Sentiment of the statement 327  is 0.125
# Sentiment of the statement 328  is -0.125
# Sentiment of the statement 329  is 0.625
# Sentiment of the statement 330  is 0.125
# Sentiment of the statement 331  is 0.125
# Sentiment of the statement 332  is -0.125
# Sentiment of the statement 333  is 0.25
# Sentiment of the statement 334  is 0.875
# Sentiment of the statement 335  is -0.125
# Sentiment of the statement 336  is 0.375
# Sentiment of the statement 337  is 0.25
# Sentiment of the statement 338  is 0.0
# Sentiment of the statement 339  is -0.5
# Sentiment of the statement 340  is 0.5
# Sentiment of the statement 341  is 0.125
# Sentiment of the statement 342  is 0.0
# Sentiment of the statement 343  is 0.75
# Sentiment of the statement 344  is 0.0
# Sentiment of the statement 345  is 0.5
# Sentiment of the statement 346  is 1.0
# Sentiment of the statement 347  is 0.0
# Sentiment of the statement 348  is 0.875
# Sentiment of the statement 349  is -0.375
# Sentiment of the statement 350  is -0.25
# Sentiment of the statement 351  is 0.125
# Sentiment of the statement 352  is 0.5
# Sentiment of the statement 353  is 0.25
# Sentiment of the statement 354  is 0.375
# Sentiment of the statement 355  is 0.625
# Sentiment of the statement 356  is 0.0
# Sentiment of the statement 357  is -0.125
# Sentiment of the statement 358  is 0.0
# Sentiment of the statement 359  is 0.5
# Sentiment of the statement 360  is 0.625
# Sentiment of the statement 361  is -0.75
# Sentiment of the statement 362  is -1.375
# Sentiment of the statement 363  is -0.125
# Sentiment of the statement 364  is 0.625
# Sentiment of the statement 365  is 0
# Sentiment of the statement 366  is 0.0
# Sentiment of the statement 367  is 1.75
# Sentiment of the statement 368  is 0.75
# Sentiment of the statement 369  is 0.125
# Sentiment of the statement 370  is -0.625
# Sentiment of the statement 371  is 0.0
# Sentiment of the statement 372  is 1.5
# Sentiment of the statement 373  is 0
# Sentiment of the statement 374  is 0.125
# Sentiment of the statement 375  is 0.0
# Sentiment of the statement 376  is 0.0
# Sentiment of the statement 377  is 0.625
# Sentiment of the statement 378  is 0.125
# Sentiment of the statement 379  is 1.25
# Sentiment of the statement 380  is 0.0
# Sentiment of the statement 381  is 0.0
# Sentiment of the statement 382  is 0.0
# Sentiment of the statement 383  is -0.125
# Sentiment of the statement 384  is 0.5
# Sentiment of the statement 385  is 0.0
# Sentiment of the statement 386  is 0.5
# Sentiment of the statement 387  is 0
# Sentiment of the statement 388  is 0.75
# Sentiment of the statement 389  is 0.75
# Sentiment of the statement 390  is 0.5
# Sentiment of the statement 391  is -0.75
# Sentiment of the statement 392  is -0.25
# Sentiment of the statement 393  is 0.125
# Sentiment of the statement 394  is 0.75
# Sentiment of the statement 395  is -0.75
# Sentiment of the statement 396  is 0.0
# Sentiment of the statement 397  is 1.0
# Sentiment of the statement 398  is 0.5
# Sentiment of the statement 399  is 0.5
# Sentiment of the statement 400  is 0.75
# Sentiment of the statement 401  is 0.0
# Sentiment of the statement 402  is -0.25
# Sentiment of the statement 403  is 0.25
# Sentiment of the statement 404  is 0.0
# Sentiment of the statement 405  is -0.125
# Sentiment of the statement 406  is 0.25
# Sentiment of the statement 407  is 0.625
# Sentiment of the statement 408  is 0.0
# Sentiment of the statement 409  is 0.0
# Sentiment of the statement 410  is 0.25
# Sentiment of the statement 411  is 0.0
# Sentiment of the statement 412  is -0.125
# Sentiment of the statement 413  is -0.375
# Sentiment of the statement 414  is 0.375
# Sentiment of the statement 415  is 0.5
# Sentiment of the statement 416  is 0.0
# Sentiment of the statement 417  is 0.0
# Sentiment of the statement 418  is 0.0
# Sentiment of the statement 419  is 0.0
# Sentiment of the statement 420  is 0.125
# Sentiment of the statement 421  is 0.0
# Sentiment of the statement 422  is 0.0
# Sentiment of the statement 423  is 1.625
# Sentiment of the statement 424  is 0.125
# Sentiment of the statement 425  is -1.625
# Sentiment of the statement 426  is 0.0
# Sentiment of the statement 427  is 0.75
# Sentiment of the statement 428  is 0
# Sentiment of the statement 429  is 0.75
# Sentiment of the statement 430  is 1.625
# Sentiment of the statement 431  is 0.625
# Sentiment of the statement 432  is 0.625
# Sentiment of the statement 433  is 0.375
# Sentiment of the statement 434  is 0.0
# Sentiment of the statement 435  is 0.375
# Sentiment of the statement 436  is -0.75
# Sentiment of the statement 437  is -0.5
# Sentiment of the statement 438  is 0.25
# Sentiment of the statement 439  is 0.25
# Sentiment of the statement 440  is 0.0
# Sentiment of the statement 441  is 0.0
# Sentiment of the statement 442  is -0.375
# Sentiment of the statement 443  is 0
# Sentiment of the statement 444  is 0.25
# Sentiment of the statement 445  is -0.375
# Sentiment of the statement 446  is 0.0
# Sentiment of the statement 447  is -0.125
# Sentiment of the statement 448  is 0.125
# Sentiment of the statement 449  is 0.5
# Sentiment of the statement 450  is 0
# Sentiment of the statement 451  is 0.625
# Sentiment of the statement 452  is 0
# Sentiment of the statement 453  is 0.5
# Sentiment of the statement 454  is 0.875
# Sentiment of the statement 455  is 0.0
# Sentiment of the statement 456  is 0.375
# Sentiment of the statement 457  is 0.5
# Sentiment of the statement 458  is 0.0
# Sentiment of the statement 459  is -0.5
# Sentiment of the statement 460  is 0.375
# Sentiment of the statement 461  is 0.75
# Sentiment of the statement 462  is -0.125
# Sentiment of the statement 463  is 0.125
# Sentiment of the statement 464  is 0.0
# Sentiment of the statement 465  is 0.875
# Sentiment of the statement 466  is 0.125
# Sentiment of the statement 467  is 0.875
# Sentiment of the statement 468  is 0.0
# Sentiment of the statement 469  is -0.75
# Sentiment of the statement 470  is 0.0
# Sentiment of the statement 471  is 0.625
# Sentiment of the statement 472  is 0.25
# Sentiment of the statement 473  is 0.0
# Sentiment of the statement 474  is -1.625
# Sentiment of the statement 475  is -0.125
# Sentiment of the statement 476  is 1.75
# Sentiment of the statement 477  is 0.25
# Sentiment of the statement 478  is 0.5
# Sentiment of the statement 479  is 1.375
# Sentiment of the statement 480  is 0.0
# Sentiment of the statement 481  is 0.875
# Sentiment of the statement 482  is -0.125
# Sentiment of the statement 483  is 0.625
# Sentiment of the statement 484  is 0.0
# Sentiment of the statement 485  is -0.125
# Sentiment of the statement 486  is 0.125
# Sentiment of the statement 487  is 0.375
# Sentiment of the statement 488  is 0.125
# Sentiment of the statement 489  is -0.625
# Sentiment of the statement 490  is -0.125
# Sentiment of the statement 491  is 0.5
# Sentiment of the statement 492  is 0.75
# Sentiment of the statement 493  is 0.0
# Sentiment of the statement 494  is 0.125
# Sentiment of the statement 495  is 1.0
# Sentiment of the statement 496  is 0.0
# Sentiment of the statement 497  is 0.125
# Sentiment of the statement 498  is 0.125
# Sentiment of the statement 499  is -0.25
# Sentiment of the statement 500  is -0.375
# Sentiment of the statement 501  is -0.125
# Sentiment of the statement 502  is -1.125
# Sentiment of the statement 503  is 1.0
# Sentiment of the statement 504  is -0.5
# Sentiment of the statement 505  is 0.125
# Sentiment of the statement 506  is 0.125
# Sentiment of the statement 507  is 0.0
# Sentiment of the statement 508  is -0.625
# Sentiment of the statement 509  is 0.375
# Sentiment of the statement 510  is -0.625
# Sentiment of the statement 511  is 0.0
# Sentiment of the statement 512  is 0.25
# Sentiment of the statement 513  is 0.0
# Sentiment of the statement 514  is 0.125
# Sentiment of the statement 515  is -0.375
# Sentiment of the statement 516  is 0.5
# Sentiment of the statement 517  is 1.5
# Sentiment of the statement 518  is 0.125
# Sentiment of the statement 519  is -0.25
# Sentiment of the statement 520  is 0.0
# Sentiment of the statement 521  is 0.375
# Sentiment of the statement 522  is -0.375
# Sentiment of the statement 523  is 0.0
# Sentiment of the statement 524  is -0.625
# Sentiment of the statement 525  is 0.125
# Sentiment of the statement 526  is -0.5
# Sentiment of the statement 527  is 0.75
# Sentiment of the statement 528  is 0.25
# Sentiment of the statement 529  is 0.875
# Sentiment of the statement 530  is 0.625
# Sentiment of the statement 531  is -0.375
# Sentiment of the statement 532  is -0.875
# Sentiment of the statement 533  is 0.0
# Sentiment of the statement 534  is 0.75
# Sentiment of the statement 535  is 0.25
# Sentiment of the statement 536  is 0.125
# Sentiment of the statement 537  is 0.5
# Sentiment of the statement 538  is 0.0
# Sentiment of the statement 539  is -1.125
# Sentiment of the statement 540  is 1.25
# Sentiment of the statement 541  is 0.25
# Sentiment of the statement 542  is 0.875
# Sentiment of the statement 543  is 0.75
# Sentiment of the statement 544  is 0.0
# Sentiment of the statement 545  is 0.75
# Sentiment of the statement 546  is 0.375
# Sentiment of the statement 547  is 0.5
# Sentiment of the statement 548  is -0.125
# Sentiment of the statement 549  is 0.375
# Sentiment of the statement 550  is 0.25
# Sentiment of the statement 551  is 0
# Sentiment of the statement 552  is 0.125
# Sentiment of the statement 553  is 0.75
# Sentiment of the statement 554  is 0.5
# Sentiment of the statement 555  is -0.75
# Sentiment of the statement 556  is 0.0
# Sentiment of the statement 557  is 0.0
# Sentiment of the statement 558  is 0.125
# Sentiment of the statement 559  is 0
# Sentiment of the statement 560  is -0.5
# Sentiment of the statement 561  is 0.25
# Sentiment of the statement 562  is 0.0
# Sentiment of the statement 563  is 0.125
# Sentiment of the statement 564  is 0.125
# Sentiment of the statement 565  is -0.375
# Sentiment of the statement 566  is -0.25
# Sentiment of the statement 567  is 1.25
# Sentiment of the statement 568  is -1.625
# Sentiment of the statement 569  is -0.75
# Sentiment of the statement 570  is 0.5
# Sentiment of the statement 571  is -0.25
# Sentiment of the statement 572  is 0.375
# Sentiment of the statement 573  is -0.75
# Sentiment of the statement 574  is 1.0
# Sentiment of the statement 575  is 0.5
# Sentiment of the statement 576  is 0.25
# Sentiment of the statement 577  is 0.625
# Sentiment of the statement 578  is 0.375
# Sentiment of the statement 579  is 0.625
# Sentiment of the statement 580  is -0.875
# Sentiment of the statement 581  is -0.375
# Sentiment of the statement 582  is 0.25
# Sentiment of the statement 583  is 0.0
# Sentiment of the statement 584  is 0.375
# Sentiment of the statement 585  is -0.5
# Sentiment of the statement 586  is 0.25
# Sentiment of the statement 587  is -0.25
# Sentiment of the statement 588  is 0.0
# Sentiment of the statement 589  is 0
# Sentiment of the statement 590  is -0.75
# Sentiment of the statement 591  is 0.375
# Sentiment of the statement 592  is 0.0
# Sentiment of the statement 593  is 1.0
# Sentiment of the statement 594  is -1.875
# Sentiment of the statement 595  is 1.375
# Sentiment of the statement 596  is -0.625
# Sentiment of the statement 597  is -1.375
# Sentiment of the statement 598  is 0.0
# Sentiment of the statement 599  is 1.5
# Sentiment of the statement 600  is 0.25
# Sentiment of the statement 601  is 1.0
# Sentiment of the statement 602  is 0.875
# Sentiment of the statement 603  is 0
# Sentiment of the statement 604  is -1.625
# Sentiment of the statement 605  is -0.625
# Sentiment of the statement 606  is -0.625
# Sentiment of the statement 607  is -0.125
# Sentiment of the statement 608  is -0.75
# Sentiment of the statement 609  is -0.5
# Sentiment of the statement 610  is -0.875
# Sentiment of the statement 611  is -0.5
# Sentiment of the statement 612  is -0.375
# Sentiment of the statement 613  is -0.375
# Sentiment of the statement 614  is -0.625
# Sentiment of the statement 615  is 0.5
# Sentiment of the statement 616  is 1.625
# Sentiment of the statement 617  is 0.125
# Sentiment of the statement 618  is 0.125
# Sentiment of the statement 619  is 0.0
# Sentiment of the statement 620  is -1.25
# Sentiment of the statement 621  is 0.125
# Sentiment of the statement 622  is -0.625
# Sentiment of the statement 623  is 0.75
# Sentiment of the statement 624  is -0.875
# Sentiment of the statement 625  is -0.75
# Sentiment of the statement 626  is 0.125
# Sentiment of the statement 627  is -0.25
# Sentiment of the statement 628  is -0.125
# Sentiment of the statement 629  is 1.375
# Sentiment of the statement 630  is 0.0
# Sentiment of the statement 631  is 0.375
# Sentiment of the statement 632  is -1.125
# Sentiment of the statement 633  is 1.25
# Sentiment of the statement 634  is -1.25
# Sentiment of the statement 635  is 0.0
# Sentiment of the statement 636  is 0.5
# Sentiment of the statement 637  is 1.125
# Sentiment of the statement 638  is -0.625
# Sentiment of the statement 639  is 0.0
# Sentiment of the statement 640  is 0.75
# Sentiment of the statement 641  is -0.625
# Sentiment of the statement 642  is 0.5
# Sentiment of the statement 643  is 0.125
# Sentiment of the statement 644  is -0.625
# Sentiment of the statement 645  is -0.125
# Sentiment of the statement 646  is 0.25
# Sentiment of the statement 647  is -0.5
# Sentiment of the statement 648  is 1.375
# Sentiment of the statement 649  is -1.875
# Sentiment of the statement 650  is -0.625
# Sentiment of the statement 651  is -0.125
# Sentiment of the statement 652  is -0.375
# Sentiment of the statement 653  is 0.125
# Sentiment of the statement 654  is 0
# Sentiment of the statement 655  is 0.125
# Sentiment of the statement 656  is -0.625
# Sentiment of the statement 657  is 0.0
# Sentiment of the statement 658  is 0.125
# Sentiment of the statement 659  is 0.0
# Sentiment of the statement 660  is 0.125
# Sentiment of the statement 661  is -0.25
# Sentiment of the statement 662  is -0.625
# Sentiment of the statement 663  is 0.125
# Sentiment of the statement 664  is -1.125
# Sentiment of the statement 665  is -0.5
# Sentiment of the statement 666  is 0.5
# Sentiment of the statement 667  is 1.5
# Sentiment of the statement 668  is 0.375
# Sentiment of the statement 669  is -0.25
# Sentiment of the statement 670  is 0.0
# Sentiment of the statement 671  is 0.625
# Sentiment of the statement 672  is 0.125
# Sentiment of the statement 673  is -0.25
# Sentiment of the statement 674  is -0.625
# Sentiment of the statement 675  is 0.0
# Sentiment of the statement 676  is -0.5
# Sentiment of the statement 677  is -0.75
# Sentiment of the statement 678  is 0.5
# Sentiment of the statement 679  is 0.125
# Sentiment of the statement 680  is 0.375
# Sentiment of the statement 681  is 0.0
# Sentiment of the statement 682  is 0.375
# Sentiment of the statement 683  is 3.0
# Sentiment of the statement 684  is 0.5
# Sentiment of the statement 685  is -0.375
# Sentiment of the statement 686  is -1.125
# Sentiment of the statement 687  is 0.0
# Sentiment of the statement 688  is -0.25
# Sentiment of the statement 689  is 0.25
# Sentiment of the statement 690  is 0.0
# Sentiment of the statement 691  is -0.5
# Sentiment of the statement 692  is 0.0
# Sentiment of the statement 693  is 0.0
# Sentiment of the statement 694  is 0.25
# Sentiment of the statement 695  is -0.25
# Sentiment of the statement 696  is 0.75
# Sentiment of the statement 697  is -0.25
# Sentiment of the statement 698  is -2.25
# Sentiment of the statement 699  is -0.625
# Sentiment of the statement 700  is -0.25
# Sentiment of the statement 701  is -0.625
# Sentiment of the statement 702  is 0.125
# Sentiment of the statement 703  is 0.625
# Sentiment of the statement 704  is 0.0
# Sentiment of the statement 705  is -0.25
# Sentiment of the statement 706  is 0.0
# Sentiment of the statement 707  is -0.375
# Sentiment of the statement 708  is 0.0
# Sentiment of the statement 709  is 1.25
# Sentiment of the statement 710  is 0.0
# Sentiment of the statement 711  is 0.25
# Sentiment of the statement 712  is 0.25
# Sentiment of the statement 713  is 0.0
# Sentiment of the statement 714  is -0.25
# Sentiment of the statement 715  is 0.875
# Sentiment of the statement 716  is -1.625
# Sentiment of the statement 717  is 0.375
# Sentiment of the statement 718  is 0.75
# Sentiment of the statement 719  is -1.0
# Sentiment of the statement 720  is 0.125
# Sentiment of the statement 721  is 0.0
# Sentiment of the statement 722  is -0.125
# Sentiment of the statement 723  is 0.0
# Sentiment of the statement 724  is 0.5
# Sentiment of the statement 725  is -0.75
# Sentiment of the statement 726  is -0.125
# Sentiment of the statement 727  is -0.375
# Sentiment of the statement 728  is 0.375
# Sentiment of the statement 729  is 0.625
# Sentiment of the statement 730  is 0.0
# Sentiment of the statement 731  is 0.125
# Sentiment of the statement 732  is 0.625
# Sentiment of the statement 733  is 0.625
# Sentiment of the statement 734  is -0.875
# Sentiment of the statement 735  is 0.0
# Sentiment of the statement 736  is 0.0
# Sentiment of the statement 737  is 0.0
# Sentiment of the statement 738  is -0.125
# Sentiment of the statement 739  is -0.875
# Sentiment of the statement 740  is 1.125
# Sentiment of the statement 741  is 0.25
# Sentiment of the statement 742  is -0.25
# Sentiment of the statement 743  is -0.75
# Sentiment of the statement 744  is -0.625
# Sentiment of the statement 745  is 0.375
# Sentiment of the statement 746  is 0.375
# Sentiment of the statement 747  is 0.125
# Sentiment of the statement 748  is 0.125
# Sentiment of the statement 749  is -0.75
# Sentiment of the statement 750  is 0.125
# Sentiment of the statement 751  is 0.125
# Sentiment of the statement 752  is -0.125
# Sentiment of the statement 753  is 0.125
# Sentiment of the statement 754  is -1.0
# Sentiment of the statement 755  is 0.125
# Sentiment of the statement 756  is 0.25
# Sentiment of the statement 757  is -0.25
# Sentiment of the statement 758  is -0.625
# Sentiment of the statement 759  is -0.25
# Sentiment of the statement 760  is -0.25
# Sentiment of the statement 761  is 0.0
# Sentiment of the statement 762  is -0.875
# Sentiment of the statement 763  is 0.125
# Sentiment of the statement 764  is -1.25
# Sentiment of the statement 765  is -0.375
# Sentiment of the statement 766  is 0.0
# Sentiment of the statement 767  is 1.125
# Sentiment of the statement 768  is 0.25
# Sentiment of the statement 769  is 0
# Sentiment of the statement 770  is 0.125
# Sentiment of the statement 771  is 0.5
# Sentiment of the statement 772  is 0
# Sentiment of the statement 773  is 0.125
# Sentiment of the statement 774  is 0.625
# Sentiment of the statement 775  is 0.5
# Sentiment of the statement 776  is 0.0
# Sentiment of the statement 777  is 0.0
# Sentiment of the statement 778  is 0.625
# Sentiment of the statement 779  is -0.125
# Sentiment of the statement 780  is -1.625
# Sentiment of the statement 781  is 0.25
# Sentiment of the statement 782  is 0.125
# Sentiment of the statement 783  is -1.25
# Sentiment of the statement 784  is 1.125
# Sentiment of the statement 785  is -0.25
# Sentiment of the statement 786  is 0.875
# Sentiment of the statement 787  is 0.125
# Sentiment of the statement 788  is -0.25
# Sentiment of the statement 789  is 0.0
# Sentiment of the statement 790  is -0.375
# Sentiment of the statement 791  is 1.125
# Sentiment of the statement 792  is 0.875
# Sentiment of the statement 793  is -2.25
# Sentiment of the statement 794  is 0.0
# Sentiment of the statement 795  is 0.25
# Sentiment of the statement 796  is 1.875
# Sentiment of the statement 797  is -0.125
# Sentiment of the statement 798  is 1.0
# Sentiment of the statement 799  is -0.125
# Sentiment of the statement 800  is -0.625
# Sentiment of the statement 801  is 0.125
# Sentiment of the statement 802  is 1.25
# Sentiment of the statement 803  is 0.0
# Sentiment of the statement 804  is 0.125
# Sentiment of the statement 805  is 0.125
# Sentiment of the statement 806  is 0.625
# Sentiment of the statement 807  is 0.125
# Sentiment of the statement 808  is 0.25
# Sentiment of the statement 809  is -0.75
# Sentiment of the statement 810  is 0.0
# Sentiment of the statement 811  is -0.375
# Sentiment of the statement 812  is -1.125
# Sentiment of the statement 813  is -0.375
# Sentiment of the statement 814  is 0.25
# Sentiment of the statement 815  is 0.125
# Sentiment of the statement 816  is 1.0
# Sentiment of the statement 817  is -0.75
# Sentiment of the statement 818  is -0.5
# Sentiment of the statement 819  is 0.5
# Sentiment of the statement 820  is -0.5
# Sentiment of the statement 821  is 0.0
# Sentiment of the statement 822  is 0.5
# Sentiment of the statement 823  is 0.5
# Sentiment of the statement 824  is 0.0
# Sentiment of the statement 825  is 0.125
# Sentiment of the statement 826  is 0.0
# Sentiment of the statement 827  is 0.125
# Sentiment of the statement 828  is -0.625
# Sentiment of the statement 829  is -0.75
# Sentiment of the statement 830  is -0.75
# Sentiment of the statement 831  is 0.375
# Sentiment of the statement 832  is 0.375
# Sentiment of the statement 833  is 0.125
# Sentiment of the statement 834  is 0.125
# Sentiment of the statement 835  is 0.125
# Sentiment of the statement 836  is 1.25
# Sentiment of the statement 837  is 0.125
# Sentiment of the statement 838  is -0.5
# Sentiment of the statement 839  is -1.125
# Sentiment of the statement 840  is -0.125
# Sentiment of the statement 841  is 0.0
# Sentiment of the statement 842  is 0.375
# Sentiment of the statement 843  is 0.125
# Sentiment of the statement 844  is 0.0
# Sentiment of the statement 845  is 0.125
# Sentiment of the statement 846  is 1.125
# Sentiment of the statement 847  is 0.0
# Sentiment of the statement 848  is -0.875
# Sentiment of the statement 849  is 0.375
# Sentiment of the statement 850  is 0.0
# Sentiment of the statement 851  is -1.0
# Sentiment of the statement 852  is 0.75
# Sentiment of the statement 853  is 0.0
# Sentiment of the statement 854  is -1.0
# Sentiment of the statement 855  is 0
# Sentiment of the statement 856  is 0.5
# Sentiment of the statement 857  is 0.0
# Sentiment of the statement 858  is 0.125
# Sentiment of the statement 859  is 0.25
# Sentiment of the statement 860  is -0.125
# Sentiment of the statement 861  is -0.625
# Sentiment of the statement 862  is 0.5
# Sentiment of the statement 863  is 0
# Sentiment of the statement 864  is 0.125
# Sentiment of the statement 865  is -0.625
# Sentiment of the statement 866  is 0.625
# Sentiment of the statement 867  is -0.25
# Sentiment of the statement 868  is 0.25
# Sentiment of the statement 869  is 0.0
# Sentiment of the statement 870  is 0.125
# Sentiment of the statement 871  is 0.125
# Sentiment of the statement 872  is 0.0
# Sentiment of the statement 873  is 0.625
# Sentiment of the statement 874  is -0.25
# Sentiment of the statement 875  is -0.25
# Sentiment of the statement 876  is 0.625
# Sentiment of the statement 877  is 0.0
# Sentiment of the statement 878  is 0.5
# Sentiment of the statement 879  is 1.0
# Sentiment of the statement 880  is 0.375
# Sentiment of the statement 881  is 0.5
# Sentiment of the statement 882  is 0.0
# Sentiment of the statement 883  is 0.5
# Sentiment of the statement 884  is 0.125
# Sentiment of the statement 885  is -0.5
# Sentiment of the statement 886  is 0.125
# Sentiment of the statement 887  is 0.875
# Sentiment of the statement 888  is -0.375
# Sentiment of the statement 889  is 0.125
# Sentiment of the statement 890  is -0.625
# Sentiment of the statement 891  is -0.375
# Sentiment of the statement 892  is -0.5
# Sentiment of the statement 893  is -0.5
# Sentiment of the statement 894  is 0.125
# Sentiment of the statement 895  is 1.5
# Sentiment of the statement 896  is 0.0
# Sentiment of the statement 897  is 0.375
# Sentiment of the statement 898  is 0.125
# Sentiment of the statement 899  is 0.875
# Sentiment of the statement 900  is -0.625
# Sentiment of the statement 901  is 0.375
# Sentiment of the statement 902  is -1.25
# Sentiment of the statement 903  is -0.5
# Sentiment of the statement 904  is 0.25
# Sentiment of the statement 905  is 0.5
# Sentiment of the statement 906  is 0.125
# Sentiment of the statement 907  is 0.25
# Sentiment of the statement 908  is 0.0
# Sentiment of the statement 909  is 0.125
# Sentiment of the statement 910  is -0.25
# Sentiment of the statement 911  is 0.0
# Sentiment of the statement 912  is 0.5
# Sentiment of the statement 913  is 0.125
# Sentiment of the statement 914  is 0.125
# Sentiment of the statement 915  is -0.625
# Sentiment of the statement 916  is 0.625
# Sentiment of the statement 917  is 0.75
# Sentiment of the statement 918  is -0.25
# Sentiment of the statement 919  is 0.0
# Sentiment of the statement 920  is 0.0
# Sentiment of the statement 921  is 0.0
# Sentiment of the statement 922  is 0.0
# Sentiment of the statement 923  is -0.5
# Sentiment of the statement 924  is 0.75
# Sentiment of the statement 925  is -0.625
# Sentiment of the statement 926  is 0.125
# Sentiment of the statement 927  is 0.25
# Sentiment of the statement 928  is 0.125
# Sentiment of the statement 929  is -0.375
# Sentiment of the statement 930  is -2.25
# Sentiment of the statement 931  is -0.125
# Sentiment of the statement 932  is -1.125
# Sentiment of the statement 933  is -0.875
# Sentiment of the statement 934  is -0.375
# Sentiment of the statement 935  is 0.0
# Sentiment of the statement 936  is 0
# Sentiment of the statement 937  is -0.125
# Sentiment of the statement 938  is 0.125
# Sentiment of the statement 939  is -0.75
# Sentiment of the statement 940  is -1.375
# Sentiment of the statement 941  is 0.375
# Sentiment of the statement 942  is -0.125
# Sentiment of the statement 943  is -1.375
# Sentiment of the statement 944  is 0.0
# Sentiment of the statement 945  is 0.125
# Sentiment of the statement 946  is -1.0
# Sentiment of the statement 947  is -0.25
# Sentiment of the statement 948  is 1.375
# Sentiment of the statement 949  is 0.5
# Sentiment of the statement 950  is 0.0
# Sentiment of the statement 951  is -0.875
# Sentiment of the statement 952  is -0.25
# Sentiment of the statement 953  is 0.0
# Sentiment of the statement 954  is 0.25
# Sentiment of the statement 955  is 0.125
# Sentiment of the statement 956  is 0.0
# Sentiment of the statement 957  is -1.375
# Sentiment of the statement 958  is -0.5
# Sentiment of the statement 959  is -0.25
# Sentiment of the statement 960  is -0.875
# Sentiment of the statement 961  is -0.125
# Sentiment of the statement 962  is 0.25
# Sentiment of the statement 963  is -0.875
# Sentiment of the statement 964  is 0.0
# Sentiment of the statement 965  is 0.0
# Sentiment of the statement 966  is -1.5
# Sentiment of the statement 967  is 0.125
# Sentiment of the statement 968  is 1.375
# Sentiment of the statement 969  is -1.0
# Sentiment of the statement 970  is -0.125
# Sentiment of the statement 971  is 0.75
# Sentiment of the statement 972  is 0.0
# Sentiment of the statement 973  is 0.5
# Sentiment of the statement 974  is -0.375
# Sentiment of the statement 975  is 0.0
# Sentiment of the statement 976  is 0.0
# Sentiment of the statement 977  is -0.375
# Sentiment of the statement 978  is 0.125
# Sentiment of the statement 979  is -0.125
# Sentiment of the statement 980  is 0.25
# Sentiment of the statement 981  is 0
# Sentiment of the statement 982  is -0.25
# Sentiment of the statement 983  is 0.0
# Sentiment of the statement 984  is 0.75
# Sentiment of the statement 985  is -0.25
# Sentiment of the statement 986  is 0.625
# Sentiment of the statement 987  is -0.25
# Sentiment of the statement 988  is 0.0
# Sentiment of the statement 989  is 0.375
# Sentiment of the statement 990  is 0.375
# Sentiment of the statement 991  is -1.375
# Sentiment of the statement 992  is 0.125
# Sentiment of the statement 993  is 0.125
# Sentiment of the statement 994  is 0.875
# Sentiment of the statement 995  is -0.75
# Sentiment of the statement 996  is -0.875
# Sentiment of the statement 997  is 0.125
# Sentiment of the statement 998  is 0.125
# Sentiment of the statement 999  is 0.25
